# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn .preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from skimage import feature
from imutils import build_montages
from imutils import paths
import numpy as np
import argparse
import cv2
import os
import xgboost as xgb

# %%
def quantify_image(image):
    # compute the HOG feature vector for the input image
    features = feature.hog(image, 
                           orientations=9,
                           pixels_per_cell=(10, 10),
                           cells_per_block=(2, 2),
                           transform_sqrt=True, 
                           block_norm="L1")
    return features

# %%
def load_split(path):
    # grab the list of images in the input directory,
    # then initialize the list of data(i.e., images) and class labels
    imagePaths = list(paths.list_images(path))
#     print(imagePaths[0])
    data = []
    labels = []
    
    # loop over the image paths
    for imagePath in imagePaths:
        # extract the class label from the filename
        label = imagePath.split(os.path.sep)[-2]
        # load the input image, convert it to grayscale, 
        # and resize it to 200x2000 pixels, ignoring aspect ratio
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = cv2.resize(image, (200,200))
        # Threshold the image such that the drawing appears as white on a black background
        image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
        # quantify the image
        features = quantify_image(image)
        # update the data and labels lists, respectively
        data.append(features)
        labels.append(label)
    return (np.array(data), np.array(labels))

# %% [markdown]
# ### Data loading and pre-processing

# %%
dataset_path = r'dataset\wave'
trial_num = 5
trainingPath = os.path.sep.join([dataset_path,"training"])
testingPath = os.path.sep.join([dataset_path, "testing"])

# load the traning and testing data
print("[INFO] loading data...")
(trainX, trainY) = load_split(trainingPath)
(testX, testY) = load_split(testingPath)

# Encode the labels as integers
le = LabelEncoder()
trainY = le.fit_transform(trainY)
testY = le.transform(testY)

#initialize or trials dicitonary
trials = {}
# Out:
# [INFO] loading data...

# %%
trainX.shape
# Out:
# (0,)

# %% [markdown]
# ### Model training with `Random Forest`, and performance displayed in confusion metrics

# %%
# loop over the number of trials to run
for i in range(0, trial_num):
    # train the model
    print(f"[INFO] training model {i+1} of {trial_num}...")
    model = RandomForestClassifier(n_estimators=100)
    model.fit(trainX, trainY)
    
    # make predictions on the testing data and initialize a dictionary to store our computed metreics
    predictions = model.predict(testX)
    metrics = {}
    
    # compute the confusion matrix and use it to derive the raw accuracy, ensitivity, and specificity
    cm = confusion_matrix(testY, predictions).flatten()
    (tn, fp, fn, tp) = cm
    metrics["acc"] = (tp + tn) / float(cm.sum())
    metrics["sensitivity"] = tp / float(tp + fn)
    metrics["specificity"] = tn / float(tn + fp)
    
    # loop over the metrics
    for (k,v) in metrics.items():
        # update the trialas dictionary with the list of values for the current metric
        l = trials.get(k, [])
        l.append(v)
        trials[k] = l

# loop over our metrics
for metric in ("acc", "sensitivity", "specificity"):
    # grab the list of values for the current metric, then compute the mean and standard deviation
    values = trials[metric]
    mean = np.mean(values)
    std = np.std(values)
    
    # show the computed metrics for the statistic
    print(metric)
    print('='*len(metric))
    print(f'mean={mean:.4f}, std={std:.4f} \n')
# Out:
# [INFO] training model 1 of 5...
# [INFO] training model 2 of 5...
# [INFO] training model 3 of 5...
# [INFO] training model 4 of 5...
# [INFO] training model 5 of 5...
# acc
# ===
# mean=0.8133, std=0.0400
#
# sensitivity
# ===========
# mean=0.7467, std=0.0777
#
# specificity
# ===========
# mean=0.8800, std=0.0267

# %% [markdown]
# ### Hyper parameter tunining for RF

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (72, 12996)
# (72,)

# %%
from hyperopt import space_eval, hp, tpe, STATUS_OK, Trials, fmin
from hyperopt.pyll import scope
from sklearn.model_selection import cross_val_score, KFold

# %%
# Bayesian optimization for RandomForest
space = {
        'n_estimators' : hp.quniform('n_estimators', 100, 1000, 25),
        'max_depth' : hp.quniform('max_depth', 1,20,1),
        'max_features': hp.choice('max_features', ['auto','sqrt','log2', 0.5, None]),
        'min_samples_leaf': hp.quniform('min_samples_leaf', 4,30,2),
}
trial = Trials()
def hyperopt_RandomForest(space):
    model = RandomForestClassifier(n_estimators= int(space['n_estimators']),
                                   max_features= space['max_features'],
                                   max_depth= int(space['max_depth']),
                                   min_samples_leaf= int(space['min_samples_leaf'])                        
                           )
    
    score = cross_val_score(model,
                            trainX, 
                            trainY, 
                            cv  = 5,
                            scoring='accuracy'                            
                           )
    
    print(f"Accuracy Score {score.mean():.3f} params {space}")
    return {'loss':(1 - score.mean()), 'status': STATUS_OK}
best = fmin(fn=hyperopt_RandomForest,
            space=space,
            algo=tpe.suggest,
            trials=trial,
            max_evals=300)
print(best)
clf = RandomForestClassifier(n_estimators= int(best['n_estimators']),
                                           max_features= ['auto','sqrt','log2', 0.5, None][best['max_features']],
                                           max_depth= int(best['max_depth']),
                                           min_samples_leaf= int(best['min_samples_leaf']))                      
                           
# final_score3 = cross_val_score(clf,
#                                trainX,
#                                trainY,
#                                cv  = 5,
#                                scoring='accuracy'                            
#                        )


print('Cooresponding loss:', final_score3.mean(), sep='\n')
# Out:
# Accuracy Score 0.655 params {'max_depth': 14.0, 'max_features': 'auto', 'min_samples_leaf': 8.0, 'n_estimators': 550.0}
# Accuracy Score 0.500 params {'max_depth': 17.0, 'max_features': 'log2', 'min_samples_leaf': 24.0, 'n_estimators': 925.0}
# Accuracy Score 0.500 params {'max_depth': 7.0, 'max_features': 'auto', 'min_samples_leaf': 30.0, 'n_estimators': 125.0}
# Accuracy Score 0.629 params {'max_depth': 9.0, 'max_features': 'sqrt', 'min_samples_leaf': 12.0, 'n_estimators': 625.0}
# Accuracy Score 0.500 params {'max_depth': 17.0, 'max_features': 'auto', 'min_samples_leaf': 26.0, 'n_estimators': 550.0}
# Accuracy Score 0.500 params {'max_depth': 16.0, 'max_features': 'sqrt', 'min_samples_leaf': 26.0, 'n_estimators': 250.0}
# Accuracy Score 0.684 params {'max_depth': 13.0, 'max_features': 'sqrt', 'min_samples_leaf': 10.0, 'n_estimators': 200.0}
# Accuracy Score 0.598 params {'max_depth': 17.0, 'max_features': 0.5, 'min_samples_leaf': 12.0, 'n_estimators': 600.0}
# Accuracy Score 0.500 params {'max_depth': 9.0, 'max_features': None, 'min_samples_leaf': 28.0, 'n_estimators': 775.0}
# Accuracy Score 0.500 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 24.0, 'n_estimators': 175.0}
# Accuracy Score 0.641 params {'max_depth': 1.0, 'max_features': 'sqrt', 'min_samples_leaf': 8.0, 'n_estimators': 350.0}
# Accuracy Score 0.500 params {'max_depth': 19.0, 'max_features': 0.5, 'min_samples_leaf': 26.0, 'n_estimators': 225.0}
# Accuracy Score 0.684 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 500.0}
# Accuracy Score 0.614 params {'max_depth': 14.0, 'max_features': None, 'min_samples_leaf': 12.0, 'n_estimators': 325.0}
# Accuracy Score 0.614 params {'max_depth': 6.0, 'max_features': 0.5, 'min_samples_leaf': 14.0, 'n_estimators': 450.0}
# Accuracy Score 0.629 params {'max_depth': 16.0, 'max_features': None, 'min_samples_leaf': 10.0, 'n_estimators': 875.0}
# Accuracy Score 0.696 params {'max_depth': 9.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 200.0}
# Accuracy Score 0.629 params {'max_depth': 19.0, 'max_features': 0.5, 'min_samples_leaf': 8.0, 'n_estimators': 825.0}
# Accuracy Score 0.543 params {'max_depth': 19.0, 'max_features': 'log2', 'min_samples_leaf': 20.0, 'n_estimators': 425.0}
# Accuracy Score 0.543 params {'max_depth': 13.0, 'max_features': 0.5, 'min_samples_leaf': 22.0, 'n_estimators': 325.0}
# Accuracy Score 0.671 params {'max_depth': 11.0, 'max_features': 'sqrt', 'min_samples_leaf': 16.0, 'n_estimators': 100.0}
# Accuracy Score 0.671 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 225.0}
# Accuracy Score 0.668 params {'max_depth': 11.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 100.0}
# Accuracy Score 0.668 params {'max_depth': 9.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 700.0}
# Accuracy Score 0.698 params {'max_depth': 12.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 375.0}
# Accuracy Score 0.738 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 400.0}
# Accuracy Score 0.629 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 18.0, 'n_estimators': 425.0}
# Accuracy Score 0.680 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 375.0}
# Accuracy Score 0.714 params {'max_depth': 12.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 500.0}
# Accuracy Score 0.641 params {'max_depth': 4.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 675.0}
# Accuracy Score 0.611 params {'max_depth': 15.0, 'max_features': 'log2', 'min_samples_leaf': 16.0, 'n_estimators': 525.0}
# Accuracy Score 0.670 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 475.0}
# Accuracy Score 0.671 params {'max_depth': 12.0, 'max_features': 'auto', 'min_samples_leaf': 14.0, 'n_estimators': 1000.0}
# Accuracy Score 0.696 params {'max_depth': 7.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 575.0}
# Accuracy Score 0.629 params {'max_depth': 10.0, 'max_features': None, 'min_samples_leaf': 14.0, 'n_estimators': 300.0}
# Accuracy Score 0.586 params {'max_depth': 14.0, 'max_features': 'auto', 'min_samples_leaf': 20.0, 'n_estimators': 675.0}
# Accuracy Score 0.657 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 750.0}
# Accuracy Score 0.686 params {'max_depth': 10.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 625.0}
# Accuracy Score 0.600 params {'max_depth': 8.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.641 params {'max_depth': 18.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 550.0}
# Accuracy Score 0.655 params {'max_depth': 15.0, 'max_features': None, 'min_samples_leaf': 10.0, 'n_estimators': 625.0}
# Accuracy Score 0.627 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 18.0, 'n_estimators': 150.0}
# Accuracy Score 0.684 params {'max_depth': 12.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 1000.0}
# Accuracy Score 0.600 params {'max_depth': 2.0, 'max_features': None, 'min_samples_leaf': 12.0, 'n_estimators': 400.0}
# Accuracy Score 0.500 params {'max_depth': 7.0, 'max_features': 0.5, 'min_samples_leaf': 24.0, 'n_estimators': 500.0}
# Accuracy Score 0.500 params {'max_depth': 17.0, 'max_features': 'auto', 'min_samples_leaf': 28.0, 'n_estimators': 925.0}
# Accuracy Score 0.671 params {'max_depth': 13.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 750.0}
# Accuracy Score 0.698 params {'max_depth': 5.0, 'max_features': 'sqrt', 'min_samples_leaf': 8.0, 'n_estimators': 475.0}
# Accuracy Score 0.600 params {'max_depth': 8.0, 'max_features': 0.5, 'min_samples_leaf': 12.0, 'n_estimators': 600.0}
# Accuracy Score 0.500 params {'max_depth': 16.0, 'max_features': 'log2', 'min_samples_leaf': 30.0, 'n_estimators': 250.0}
# Accuracy Score 0.614 params {'max_depth': 14.0, 'max_features': None, 'min_samples_leaf': 16.0, 'n_estimators': 325.0}
# Accuracy Score 0.500 params {'max_depth': 18.0, 'max_features': 'log2', 'min_samples_leaf': 22.0, 'n_estimators': 525.0}
# Accuracy Score 0.670 params {'max_depth': 20.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 450.0}
# Accuracy Score 0.629 params {'max_depth': 10.0, 'max_features': 0.5, 'min_samples_leaf': 10.0, 'n_estimators': 800.0}
# Accuracy Score 0.652 params {'max_depth': 11.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 150.0}
# Accuracy Score 0.500 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 28.0, 'n_estimators': 850.0}
# Accuracy Score 0.645 params {'max_depth': 2.0, 'max_features': 'auto', 'min_samples_leaf': 4.0, 'n_estimators': 350.0}
# Accuracy Score 0.614 params {'max_depth': 15.0, 'max_features': 'sqrt', 'min_samples_leaf': 18.0, 'n_estimators': 700.0}
# Accuracy Score 0.643 params {'max_depth': 3.0, 'max_features': None, 'min_samples_leaf': 8.0, 'n_estimators': 400.0}
# Accuracy Score 0.682 params {'max_depth': 9.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 275.0}
# Accuracy Score 0.613 params {'max_depth': 13.0, 'max_features': 0.5, 'min_samples_leaf': 20.0, 'n_estimators': 200.0}
# Accuracy Score 0.657 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 600.0}
# Accuracy Score 0.654 params {'max_depth': 7.0, 'max_features': 'sqrt', 'min_samples_leaf': 6.0, 'n_estimators': 450.0}
# Accuracy Score 0.713 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 650.0}
# Accuracy Score 0.657 params {'max_depth': 12.0, 'max_features': 'auto', 'min_samples_leaf': 16.0, 'n_estimators': 575.0}
# Accuracy Score 0.713 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 650.0}
# Accuracy Score 0.598 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 725.0}
# Accuracy Score 0.684 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 525.0}
# Accuracy Score 0.714 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 650.0}
# Accuracy Score 0.629 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 500.0}
# Accuracy Score 0.668 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 575.0}
# Accuracy Score 0.657 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 900.0}
# Accuracy Score 0.700 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 800.0}
# Accuracy Score 0.670 params {'max_depth': 11.0, 'max_features': None, 'min_samples_leaf': 6.0, 'n_estimators': 375.0}
# Accuracy Score 0.713 params {'max_depth': 10.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 475.0}
# Accuracy Score 0.571 params {'max_depth': 7.0, 'max_features': 0.5, 'min_samples_leaf': 12.0, 'n_estimators': 700.0}
# Accuracy Score 0.682 params {'max_depth': 9.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 400.0}
# Accuracy Score 0.670 params {'max_depth': 5.0, 'max_features': 'auto', 'min_samples_leaf': 8.0, 'n_estimators': 550.0}
# Accuracy Score 0.709 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 950.0}
# Accuracy Score 0.670 params {'max_depth': 13.0, 'max_features': 'sqrt', 'min_samples_leaf': 14.0, 'n_estimators': 425.0}
# Accuracy Score 0.500 params {'max_depth': 15.0, 'max_features': 'log2', 'min_samples_leaf': 22.0, 'n_estimators': 325.0}
# Accuracy Score 0.659 params {'max_depth': 16.0, 'max_features': None, 'min_samples_leaf': 4.0, 'n_estimators': 650.0}
# Accuracy Score 0.698 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 300.0}
# Accuracy Score 0.600 params {'max_depth': 8.0, 'max_features': 0.5, 'min_samples_leaf': 10.0, 'n_estimators': 750.0}
# Accuracy Score 0.682 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 500.0}
# Accuracy Score 0.713 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 600.0}
# Accuracy Score 0.655 params {'max_depth': 12.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 350.0}
# Accuracy Score 0.641 params {'max_depth': 14.0, 'max_features': 'sqrt', 'min_samples_leaf': 8.0, 'n_estimators': 775.0}
# Accuracy Score 0.627 params {'max_depth': 11.0, 'max_features': None, 'min_samples_leaf': 10.0, 'n_estimators': 450.0}
# Accuracy Score 0.654 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 225.0}
# Accuracy Score 0.600 params {'max_depth': 10.0, 'max_features': 0.5, 'min_samples_leaf': 18.0, 'n_estimators': 525.0}
# Accuracy Score 0.684 params {'max_depth': 17.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 675.0}
# Accuracy Score 0.500 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 24.0, 'n_estimators': 850.0}
# Accuracy Score 0.657 params {'max_depth': 18.0, 'max_features': 'auto', 'min_samples_leaf': 16.0, 'n_estimators': 425.0}
# Accuracy Score 0.684 params {'max_depth': 9.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 625.0}
# Accuracy Score 0.713 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 125.0}
# Accuracy Score 0.671 params {'max_depth': 7.0, 'max_features': None, 'min_samples_leaf': 8.0, 'n_estimators': 575.0}
# Accuracy Score 0.529 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 20.0, 'n_estimators': 250.0}
# Accuracy Score 0.614 params {'max_depth': 13.0, 'max_features': 0.5, 'min_samples_leaf': 12.0, 'n_estimators': 300.0}
# Accuracy Score 0.500 params {'max_depth': 14.0, 'max_features': 'log2', 'min_samples_leaf': 26.0, 'n_estimators': 725.0}
# Accuracy Score 0.696 params {'max_depth': 11.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 350.0}
# Accuracy Score 0.670 params {'max_depth': 12.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 475.0}
# Accuracy Score 0.655 params {'max_depth': 16.0, 'max_features': 'sqrt', 'min_samples_leaf': 10.0, 'n_estimators': 375.0}
# Accuracy Score 0.657 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 175.0}
# Accuracy Score 0.500 params {'max_depth': 7.0, 'max_features': None, 'min_samples_leaf': 28.0, 'n_estimators': 550.0}
# Accuracy Score 0.727 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 625.0}
# Accuracy Score 0.712 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 825.0}
# Accuracy Score 0.629 params {'max_depth': 3.0, 'max_features': 0.5, 'min_samples_leaf': 8.0, 'n_estimators': 725.0}
# Accuracy Score 0.709 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 775.0}
# Accuracy Score 0.641 params {'max_depth': 5.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 675.0}
# Accuracy Score 0.684 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 875.0}
# Accuracy Score 0.670 params {'max_depth': 4.0, 'max_features': 'sqrt', 'min_samples_leaf': 8.0, 'n_estimators': 600.0}
# Accuracy Score 0.600 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 16.0, 'n_estimators': 650.0}
# Accuracy Score 0.641 params {'max_depth': 1.0, 'max_features': None, 'min_samples_leaf': 6.0, 'n_estimators': 950.0}
# Accuracy Score 0.684 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 625.0}
# Accuracy Score 0.500 params {'max_depth': 5.0, 'max_features': 0.5, 'min_samples_leaf': 30.0, 'n_estimators': 700.0}
# Accuracy Score 0.727 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 525.0}
# Accuracy Score 0.629 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 275.0}
# Accuracy Score 0.500 params {'max_depth': 6.0, 'max_features': 'auto', 'min_samples_leaf': 26.0, 'n_estimators': 400.0}
# Accuracy Score 0.643 params {'max_depth': 4.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 425.0}
# Accuracy Score 0.500 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 24.0, 'n_estimators': 525.0}
# Accuracy Score 0.500 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 22.0, 'n_estimators': 475.0}
# Accuracy Score 0.657 params {'max_depth': 7.0, 'max_features': None, 'min_samples_leaf': 6.0, 'n_estimators': 450.0}
# Accuracy Score 0.739 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 350.0}
# Accuracy Score 0.655 params {'max_depth': 4.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 225.0}
# Accuracy Score 0.766 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 250.0}
# Accuracy Score 0.629 params {'max_depth': 20.0, 'max_features': 'auto', 'min_samples_leaf': 10.0, 'n_estimators': 125.0}
# Accuracy Score 0.668 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 175.0}
# Accuracy Score 0.612 params {'max_depth': 1.0, 'max_features': 'sqrt', 'min_samples_leaf': 18.0, 'n_estimators': 200.0}
# Accuracy Score 0.659 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 100.0}
# Accuracy Score 0.614 params {'max_depth': 2.0, 'max_features': None, 'min_samples_leaf': 20.0, 'n_estimators': 275.0}
# Accuracy Score 0.664 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 250.0}
# Accuracy Score 0.627 params {'max_depth': 1.0, 'max_features': 0.5, 'min_samples_leaf': 12.0, 'n_estimators': 300.0}
# Accuracy Score 0.655 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 150.0}
# Accuracy Score 0.627 params {'max_depth': 4.0, 'max_features': 'auto', 'min_samples_leaf': 12.0, 'n_estimators': 350.0}
# Accuracy Score 0.671 params {'max_depth': 7.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 175.0}
# Accuracy Score 0.641 params {'max_depth': 9.0, 'max_features': 'sqrt', 'min_samples_leaf': 10.0, 'n_estimators': 325.0}
# Accuracy Score 0.570 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 16.0, 'n_estimators': 225.0}
# Accuracy Score 0.614 params {'max_depth': 3.0, 'max_features': None, 'min_samples_leaf': 14.0, 'n_estimators': 150.0}
# Accuracy Score 0.668 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 375.0}
# Accuracy Score 0.657 params {'max_depth': 5.0, 'max_features': 0.5, 'min_samples_leaf': 4.0, 'n_estimators': 200.0}
# Accuracy Score 0.682 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 250.0}
# Accuracy Score 0.670 params {'max_depth': 4.0, 'max_features': 'auto', 'min_samples_leaf': 8.0, 'n_estimators': 100.0}
# Accuracy Score 0.655 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 300.0}
# Accuracy Score 0.698 params {'max_depth': 10.0, 'max_features': 'sqrt', 'min_samples_leaf': 18.0, 'n_estimators': 400.0}
# Accuracy Score 0.739 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 500.0}
# Accuracy Score 0.698 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 500.0}
# Accuracy Score 0.668 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 375.0}
# Accuracy Score 0.741 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 325.0}
# Accuracy Score 0.682 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 450.0}
# Accuracy Score 0.698 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 325.0}
# Accuracy Score 0.754 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 325.0}
# Accuracy Score 0.725 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 325.0}
# Accuracy Score 0.668 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 125.0}
# Accuracy Score 0.711 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.659 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 200.0}
# Accuracy Score 0.682 params {'max_depth': 7.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 350.0}
# Accuracy Score 0.727 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 425.0}
# Accuracy Score 0.696 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 400.0}
# Accuracy Score 0.571 params {'max_depth': 1.0, 'max_features': None, 'min_samples_leaf': 10.0, 'n_estimators': 300.0}
# Accuracy Score 0.668 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 250.0}
# Accuracy Score 0.713 params {'max_depth': 9.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 175.0}
# Accuracy Score 0.641 params {'max_depth': 4.0, 'max_features': 0.5, 'min_samples_leaf': 8.0, 'n_estimators': 475.0}
# Accuracy Score 0.654 params {'max_depth': 6.0, 'max_features': 'auto', 'min_samples_leaf': 4.0, 'n_estimators': 275.0}
# Accuracy Score 0.757 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 225.0}
# Accuracy Score 0.629 params {'max_depth': 7.0, 'max_features': 'sqrt', 'min_samples_leaf': 10.0, 'n_estimators': 225.0}
# Accuracy Score 0.655 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 150.0}
# Accuracy Score 0.629 params {'max_depth': 3.0, 'max_features': None, 'min_samples_leaf': 14.0, 'n_estimators': 225.0}
# Accuracy Score 0.738 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 100.0}
# Accuracy Score 0.629 params {'max_depth': 6.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 125.0}
# Accuracy Score 0.645 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 200.0}
# Accuracy Score 0.655 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 175.0}
# Accuracy Score 0.641 params {'max_depth': 2.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 250.0}
# Accuracy Score 0.529 params {'max_depth': 3.0, 'max_features': 'sqrt', 'min_samples_leaf': 22.0, 'n_estimators': 275.0}
# Accuracy Score 0.657 params {'max_depth': 7.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 325.0}
# Accuracy Score 0.711 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 300.0}
# Accuracy Score 0.684 params {'max_depth': 9.0, 'max_features': None, 'min_samples_leaf': 8.0, 'n_estimators': 150.0}
# Accuracy Score 0.500 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 24.0, 'n_estimators': 250.0}
# Accuracy Score 0.614 params {'max_depth': 2.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 225.0}
# Accuracy Score 0.557 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 20.0, 'n_estimators': 375.0}
# Accuracy Score 0.614 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 125.0}
# Accuracy Score 0.500 params {'max_depth': 3.0, 'max_features': 'auto', 'min_samples_leaf': 30.0, 'n_estimators': 200.0}
# Accuracy Score 0.682 params {'max_depth': 4.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 375.0}
# Accuracy Score 0.641 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 16.0, 'n_estimators': 350.0}
# Accuracy Score 0.670 params {'max_depth': 7.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 275.0}
# Accuracy Score 0.500 params {'max_depth': 2.0, 'max_features': None, 'min_samples_leaf': 28.0, 'n_estimators': 450.0}
# Accuracy Score 0.670 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 425.0}
# Accuracy Score 0.600 params {'max_depth': 19.0, 'max_features': 0.5, 'min_samples_leaf': 10.0, 'n_estimators': 175.0}
# Accuracy Score 0.639 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 325.0}
# Accuracy Score 0.684 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 400.0}
# Accuracy Score 0.600 params {'max_depth': 3.0, 'max_features': 'auto', 'min_samples_leaf': 14.0, 'n_estimators': 200.0}
# Accuracy Score 0.682 params {'max_depth': 4.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 250.0}
# Accuracy Score 0.657 params {'max_depth': 10.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 375.0}
# Accuracy Score 0.598 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 100.0}
# Accuracy Score 0.629 params {'max_depth': 3.0, 'max_features': None, 'min_samples_leaf': 12.0, 'n_estimators': 300.0}
# Accuracy Score 0.738 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 550.0}
# Accuracy Score 0.613 params {'max_depth': 9.0, 'max_features': 0.5, 'min_samples_leaf': 8.0, 'n_estimators': 150.0}
# Accuracy Score 0.657 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 350.0}
# Accuracy Score 0.655 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 175.0}
# Accuracy Score 0.700 params {'max_depth': 6.0, 'max_features': 'auto', 'min_samples_leaf': 8.0, 'n_estimators': 225.0}
# Accuracy Score 0.657 params {'max_depth': 3.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 425.0}
# Accuracy Score 0.739 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 300.0}
# Accuracy Score 0.588 params {'max_depth': 11.0, 'max_features': 'log2', 'min_samples_leaf': 16.0, 'n_estimators': 125.0}
# Accuracy Score 0.629 params {'max_depth': 7.0, 'max_features': None, 'min_samples_leaf': 12.0, 'n_estimators': 275.0}
# Accuracy Score 0.655 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 325.0}
# Accuracy Score 0.613 params {'max_depth': 1.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 250.0}
# Accuracy Score 0.725 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 575.0}
# Accuracy Score 0.695 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 18.0, 'n_estimators': 400.0}
# Accuracy Score 0.613 params {'max_depth': 2.0, 'max_features': 'auto', 'min_samples_leaf': 14.0, 'n_estimators': 475.0}
# Accuracy Score 0.500 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 22.0, 'n_estimators': 325.0}
# Accuracy Score 0.627 params {'max_depth': 6.0, 'max_features': 'sqrt', 'min_samples_leaf': 10.0, 'n_estimators': 450.0}
# Accuracy Score 0.500 params {'max_depth': 15.0, 'max_features': 'log2', 'min_samples_leaf': 26.0, 'n_estimators': 150.0}
# Accuracy Score 0.643 params {'max_depth': 7.0, 'max_features': None, 'min_samples_leaf': 8.0, 'n_estimators': 200.0}
# Accuracy Score 0.752 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 100.0}
# Accuracy Score 0.614 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 125.0}
# Accuracy Score 0.598 params {'max_depth': 5.0, 'max_features': 0.5, 'min_samples_leaf': 12.0, 'n_estimators': 100.0}
# Accuracy Score 0.684 params {'max_depth': 10.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 150.0}
# Accuracy Score 0.571 params {'max_depth': 1.0, 'max_features': 'auto', 'min_samples_leaf': 10.0, 'n_estimators': 225.0}
# Accuracy Score 0.614 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 100.0}
# Accuracy Score 0.671 params {'max_depth': 9.0, 'max_features': 'sqrt', 'min_samples_leaf': 6.0, 'n_estimators': 175.0}
# Accuracy Score 0.587 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 100.0}
# Accuracy Score 0.679 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 125.0}
# Accuracy Score 0.655 params {'max_depth': 2.0, 'max_features': None, 'min_samples_leaf': 8.0, 'n_estimators': 250.0}
# Accuracy Score 0.696 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 200.0}
# Accuracy Score 0.614 params {'max_depth': 11.0, 'max_features': 0.5, 'min_samples_leaf': 10.0, 'n_estimators': 175.0}
# Accuracy Score 0.695 params {'max_depth': 12.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.655 params {'max_depth': 7.0, 'max_features': 'auto', 'min_samples_leaf': 12.0, 'n_estimators': 150.0}
# Accuracy Score 0.611 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 225.0}
# Accuracy Score 0.655 params {'max_depth': 1.0, 'max_features': 'sqrt', 'min_samples_leaf': 16.0, 'n_estimators': 975.0}
# Accuracy Score 0.723 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 300.0}
# Accuracy Score 0.500 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 20.0, 'n_estimators': 225.0}
# Accuracy Score 0.700 params {'max_depth': 2.0, 'max_features': None, 'min_samples_leaf': 6.0, 'n_estimators': 350.0}
# Accuracy Score 0.627 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 200.0}
# Accuracy Score 0.641 params {'max_depth': 8.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 125.0}
# Accuracy Score 0.655 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 375.0}
# Accuracy Score 0.643 params {'max_depth': 4.0, 'max_features': 'auto', 'min_samples_leaf': 4.0, 'n_estimators': 175.0}
# Accuracy Score 0.684 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 14.0, 'n_estimators': 300.0}
# Accuracy Score 0.598 params {'max_depth': 7.0, 'max_features': 'sqrt', 'min_samples_leaf': 8.0, 'n_estimators': 100.0}
# Accuracy Score 0.711 params {'max_depth': 9.0, 'max_features': 'log2', 'min_samples_leaf': 18.0, 'n_estimators': 250.0}
# Accuracy Score 0.613 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 200.0}
# Accuracy Score 0.655 params {'max_depth': 10.0, 'max_features': None, 'min_samples_leaf': 10.0, 'n_estimators': 150.0}
# Accuracy Score 0.680 params {'max_depth': 13.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 175.0}
# Accuracy Score 0.686 params {'max_depth': 17.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.713 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 350.0}
# Accuracy Score 0.637 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 225.0}
# Accuracy Score 0.670 params {'max_depth': 4.0, 'max_features': 'sqrt', 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.668 params {'max_depth': 2.0, 'max_features': 'auto', 'min_samples_leaf': 8.0, 'n_estimators': 125.0}
# Accuracy Score 0.670 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 500.0}
# Accuracy Score 0.711 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 400.0}
# Accuracy Score 0.629 params {'max_depth': 3.0, 'max_features': None, 'min_samples_leaf': 16.0, 'n_estimators': 100.0}
# Accuracy Score 0.641 params {'max_depth': 14.0, 'max_features': 'log2', 'min_samples_leaf': 12.0, 'n_estimators': 900.0}
# Accuracy Score 0.557 params {'max_depth': 6.0, 'max_features': 0.5, 'min_samples_leaf': 14.0, 'n_estimators': 425.0}
# Accuracy Score 0.711 params {'max_depth': 18.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 525.0}
# Accuracy Score 0.641 params {'max_depth': 8.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 300.0}
# Accuracy Score 0.670 params {'max_depth': 7.0, 'max_features': 'auto', 'min_samples_leaf': 10.0, 'n_estimators': 575.0}
# Accuracy Score 0.613 params {'max_depth': 19.0, 'max_features': 'sqrt', 'min_samples_leaf': 4.0, 'n_estimators': 150.0}
# Accuracy Score 0.684 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 325.0}
# Accuracy Score 0.696 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 250.0}
# Accuracy Score 0.670 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 350.0}
# Accuracy Score 0.729 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 400.0}
# Accuracy Score 0.739 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 325.0}
# Accuracy Score 0.741 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 375.0}
# Accuracy Score 0.754 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 275.0}
# Accuracy Score 0.611 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 200.0}
# Accuracy Score 0.739 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 250.0}
# Accuracy Score 0.655 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 175.0}
# Accuracy Score 0.666 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 275.0}
# Accuracy Score 0.627 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 225.0}
# Accuracy Score 0.766 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 300.0}
# Accuracy Score 0.639 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 300.0}
# Accuracy Score 0.741 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 350.0}
# Accuracy Score 0.684 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 450.0}
# Accuracy Score 0.714 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 375.0}
# Accuracy Score 0.680 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 300.0}
# Accuracy Score 0.684 params {'max_depth': 2.0, 'max_features': None, 'min_samples_leaf': 8.0, 'n_estimators': 475.0}
# Accuracy Score 0.695 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 425.0}
# Accuracy Score 0.614 params {'max_depth': 5.0, 'max_features': 0.5, 'min_samples_leaf': 8.0, 'n_estimators': 250.0}
# Accuracy Score 0.668 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 400.0}
# Accuracy Score 0.696 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 325.0}
# Accuracy Score 0.654 params {'max_depth': 1.0, 'max_features': 'auto', 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.698 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 350.0}
# Accuracy Score 0.600 params {'max_depth': 7.0, 'max_features': 'sqrt', 'min_samples_leaf': 10.0, 'n_estimators': 225.0}
# Accuracy Score 0.500 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 24.0, 'n_estimators': 375.0}
# Accuracy Score 0.729 params {'max_depth': 3.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 275.0}
# Accuracy Score 0.641 params {'max_depth': 4.0, 'max_features': None, 'min_samples_leaf': 6.0, 'n_estimators': 200.0}
# Accuracy Score 0.695 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 325.0}
# Accuracy Score 0.630 params {'max_depth': 3.0, 'max_features': 0.5, 'min_samples_leaf': 6.0, 'n_estimators': 450.0}
# Accuracy Score 0.682 params {'max_depth': 1.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 225.0}
# Accuracy Score 0.711 params {'max_depth': 5.0, 'max_features': 'log2', 'min_samples_leaf': 10.0, 'n_estimators': 425.0}
# Accuracy Score 0.627 params {'max_depth': 6.0, 'max_features': 'auto', 'min_samples_leaf': 4.0, 'n_estimators': 250.0}
# Accuracy Score 0.727 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 300.0}
# Accuracy Score 0.686 params {'max_depth': 2.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 500.0}
# Accuracy Score 0.614 params {'max_depth': 5.0, 'max_features': 'sqrt', 'min_samples_leaf': 12.0, 'n_estimators': 200.0}
# Accuracy Score 0.725 params {'max_depth': 4.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 350.0}
# Accuracy Score 0.629 params {'max_depth': 3.0, 'max_features': None, 'min_samples_leaf': 6.0, 'n_estimators': 275.0}
# Accuracy Score 0.686 params {'max_depth': 7.0, 'max_features': 'log2', 'min_samples_leaf': 8.0, 'n_estimators': 300.0}
# Accuracy Score 0.627 params {'max_depth': 1.0, 'max_features': 0.5, 'min_samples_leaf': 10.0, 'n_estimators': 400.0}
# Accuracy Score 0.739 params {'max_depth': 6.0, 'max_features': 'log2', 'min_samples_leaf': 4.0, 'n_estimators': 325.0}
# Accuracy Score 0.655 params {'max_depth': 20.0, 'max_features': 'log2', 'min_samples_leaf': 6.0, 'n_estimators': 525.0}
# Accuracy Score 0.500 params {'max_depth': 3.0, 'max_features': 'auto', 'min_samples_leaf': 30.0, 'n_estimators': 175.0}
# 100%|██████████| 300/300 [17:03<00:00,  2.43s/it, best loss: 0.23392857142857137]
# {'max_depth': 5.0, 'max_features': 2, 'min_samples_leaf': 6.0, 'n_estimators': 300.0}
# Cooresponding loss:
# 0.6839285714285714

# %%
score = [0.6,0.5, 0.5, 0.5, 0.5]

# %% [markdown]
# ## Bayesian optimization for XGBClassifier

# %%
# Define the search parameter spacs
space = {
        'max_depth': hp.quniform('max_depth', 2, 20, 1),
        'min_child_samples': hp.quniform ('min_child_samples', 1, 20, 1),
        'subsample': hp.uniform ('subsample', 0.8, 1),
        'n_estimators' : hp.quniform('n_estimators', 50,1000,25),
        'learning_rate' : hp.loguniform('learning_rate', np.log(0.005), np.log(0.2)),
        'gamma' : hp.uniform('gamma', 0, 1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.3, 1.0)
}
trial = Trials()

# Define the objective to minimize
def hyperopt_XGBClassifier(space):
    model = xgb.XGBClassifier(n_estimators= int(space['n_estimators']),
                               max_depth = int(space['max_depth']),
                               min_child_samples = space['min_child_samples'],
                               subsample = space['subsample'],
                               learning_rate= space['learning_rate'],
                               gamma = space['gamma'],
                               colsample_bytree = space['colsample_bytree']
                               )
    
    model.fit(trainX, trainY)
    
    # make predictions on the testing data and initialize a dictionary to store our computed metreics
    predictions = model.predict(testX)
    metrics = {}
    
    # compute the confusion matrix and use it to derive the raw accuracy, ensitivity, and specificity
    cm = confusion_matrix(testY, predictions).flatten()
    (tn, fp, fn, tp) = cm
    metrics["acc"] = (tp + tn) / float(cm.sum())
    print("Accuracy Score {:.3f} params {}".format(metrics["acc"], space))
    
    # Maximize the accuracy by minimize (1-accuracy)
    return {'loss':(1 - metrics["acc"]), 'status': STATUS_OK}



best = fmin(fn=hyperopt_XGBClassifier,
            space=space,
            algo=tpe.suggest,
            trials=trial,
            max_evals=500)
print(best)
clf = xgb.XGBClassifier(n_estimators = int(best['n_estimators']),
                   max_depth = int(best['max_depth']),
                   min_child_samples = best['min_child_samples'],
                   subsample = best['subsample'],
                   learning_rate = best['learning_rate'],
                   gamma = best['gamma'],
                   colsample_bytree = best['colsample_bytree'])
# final_score3 = cross_val_score(clf,
#                         train_cl[ML_columns], 
#                         train_cl['Target'], 
#                         cv  = cv,
#                         scoring='roc_auc'                            
#                        )
# clf.fit(trainX,trainY)
# final_prediction = clf.predict(testX)
# cm_final = confusion_matrix(testY,predictions).flatten()
# (tn, fp, fn, tp) = cm_final
# accuracy_final = (tp + tn) / float(cm_final.sum())


print('Cooresponding loss:', accuracy_final, sep='\n')
# Out:
# Accuracy Score 0.833 params {'colsample_bytree': 0.6103680944248027, 'gamma': 0.5724439047623937, 'learning_rate': 0.16624515548640778, 'max_depth': 9.0, 'min_child_samples': 19.0, 'n_estimators': 500.0, 'subsample': 0.8592170507317379}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8103404540412369, 'gamma': 0.6444931213198691, 'learning_rate': 0.028266758865937196, 'max_depth': 14.0, 'min_child_samples': 19.0, 'n_estimators': 675.0, 'subsample': 0.8787338410762001}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7831970267527404, 'gamma': 0.3626056250434858, 'learning_rate': 0.060040938757403906, 'max_depth': 5.0, 'min_child_samples': 3.0, 'n_estimators': 300.0, 'subsample': 0.930797607492455}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6676109250623357, 'gamma': 0.6412361578254506, 'learning_rate': 0.020682612579811882, 'max_depth': 14.0, 'min_child_samples': 15.0, 'n_estimators': 850.0, 'subsample': 0.8370209813250722}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3153444773215325, 'gamma': 0.17247983845261328, 'learning_rate': 0.1095849643564023, 'max_depth': 13.0, 'min_child_samples': 10.0, 'n_estimators': 775.0, 'subsample': 0.9346393327008852}
# Accuracy Score 0.733 params {'colsample_bytree': 0.5442943053564899, 'gamma': 0.04109002798750694, 'learning_rate': 0.006738805492538812, 'max_depth': 6.0, 'min_child_samples': 14.0, 'n_estimators': 450.0, 'subsample': 0.9057434494914177}
# Accuracy Score 0.767 params {'colsample_bytree': 0.9553071787665477, 'gamma': 0.11908735595534403, 'learning_rate': 0.11883080408824012, 'max_depth': 19.0, 'min_child_samples': 15.0, 'n_estimators': 925.0, 'subsample': 0.8079902618090635}
# Accuracy Score 0.800 params {'colsample_bytree': 0.3124464093999636, 'gamma': 0.5956224944129501, 'learning_rate': 0.0669874739130488, 'max_depth': 10.0, 'min_child_samples': 5.0, 'n_estimators': 250.0, 'subsample': 0.8075385607537464}
# Accuracy Score 0.767 params {'colsample_bytree': 0.49743811587287917, 'gamma': 0.7910106962282265, 'learning_rate': 0.015453986267823972, 'max_depth': 4.0, 'min_child_samples': 6.0, 'n_estimators': 125.0, 'subsample': 0.8830430494838883}
# Accuracy Score 0.767 params {'colsample_bytree': 0.375811982591607, 'gamma': 0.4490109985936146, 'learning_rate': 0.10758017044797606, 'max_depth': 5.0, 'min_child_samples': 16.0, 'n_estimators': 475.0, 'subsample': 0.9041500775975237}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8011765092609049, 'gamma': 0.566907515992285, 'learning_rate': 0.006735317378496286, 'max_depth': 15.0, 'min_child_samples': 10.0, 'n_estimators': 825.0, 'subsample': 0.8113594420452431}
# Accuracy Score 0.800 params {'colsample_bytree': 0.7304286089340601, 'gamma': 0.9418200853935638, 'learning_rate': 0.05313718170615866, 'max_depth': 3.0, 'min_child_samples': 3.0, 'n_estimators': 150.0, 'subsample': 0.8937484370231238}
# Accuracy Score 0.733 params {'colsample_bytree': 0.673978262313417, 'gamma': 0.47148618141781773, 'learning_rate': 0.05785578394471175, 'max_depth': 16.0, 'min_child_samples': 3.0, 'n_estimators': 450.0, 'subsample': 0.9627115516430604}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3184441745822015, 'gamma': 0.08898020379457483, 'learning_rate': 0.052313186529673227, 'max_depth': 14.0, 'min_child_samples': 10.0, 'n_estimators': 850.0, 'subsample': 0.8634355965381355}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6394719869570475, 'gamma': 0.15792478709889313, 'learning_rate': 0.00565005258995744, 'max_depth': 16.0, 'min_child_samples': 4.0, 'n_estimators': 550.0, 'subsample': 0.9668179266615429}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6084486149737567, 'gamma': 0.4087885988584612, 'learning_rate': 0.1532914062910944, 'max_depth': 6.0, 'min_child_samples': 15.0, 'n_estimators': 650.0, 'subsample': 0.8212785840071772}
# Accuracy Score 0.767 params {'colsample_bytree': 0.968166361821712, 'gamma': 0.5681847141033284, 'learning_rate': 0.030578656457375775, 'max_depth': 11.0, 'min_child_samples': 5.0, 'n_estimators': 350.0, 'subsample': 0.8751493728842292}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7886585740030532, 'gamma': 0.5548634767993014, 'learning_rate': 0.18190866323915172, 'max_depth': 20.0, 'min_child_samples': 2.0, 'n_estimators': 275.0, 'subsample': 0.8518216077306402}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6812010134516404, 'gamma': 0.9777295747492893, 'learning_rate': 0.027568545350674916, 'max_depth': 12.0, 'min_child_samples': 14.0, 'n_estimators': 100.0, 'subsample': 0.9670387928632491}
# Accuracy Score 0.767 params {'colsample_bytree': 0.934799156707824, 'gamma': 0.2683745297239789, 'learning_rate': 0.005631544051103918, 'max_depth': 6.0, 'min_child_samples': 7.0, 'n_estimators': 425.0, 'subsample': 0.8966848266033245}
# Accuracy Score 0.767 params {'colsample_bytree': 0.47945722148696873, 'gamma': 0.9741889235176544, 'learning_rate': 0.04234466304130169, 'max_depth': 2.0, 'min_child_samples': 20.0, 'n_estimators': 175.0, 'subsample': 0.9237670420106013}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7290055614629559, 'gamma': 0.8167960885518681, 'learning_rate': 0.011874794040552085, 'max_depth': 8.0, 'min_child_samples': 18.0, 'n_estimators': 600.0, 'subsample': 0.8368326484790608}
# Accuracy Score 0.733 params {'colsample_bytree': 0.8616973762022876, 'gamma': 0.8418753064897926, 'learning_rate': 0.0738783517846864, 'max_depth': 2.0, 'min_child_samples': 8.0, 'n_estimators': 200.0, 'subsample': 0.8541251759895918}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4212807246500997, 'gamma': 0.7070141525602425, 'learning_rate': 0.18626835519011473, 'max_depth': 9.0, 'min_child_samples': 12.0, 'n_estimators': 375.0, 'subsample': 0.8277341086975932}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5678293552151255, 'gamma': 0.32816267494935053, 'learning_rate': 0.08952649293673347, 'max_depth': 9.0, 'min_child_samples': 8.0, 'n_estimators': 50.0, 'subsample': 0.9958882040084478}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4220395371516048, 'gamma': 0.7323527113544446, 'learning_rate': 0.13489416588948522, 'max_depth': 8.0, 'min_child_samples': 1.0, 'n_estimators': 275.0, 'subsample': 0.8006785402848102}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4216166128671224, 'gamma': 0.7033863156100428, 'learning_rate': 0.18864650233716376, 'max_depth': 10.0, 'min_child_samples': 17.0, 'n_estimators': 350.0, 'subsample': 0.8294824688921567}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5092256735849363, 'gamma': 0.8658065143076596, 'learning_rate': 0.1910344308195698, 'max_depth': 8.0, 'min_child_samples': 12.0, 'n_estimators': 525.0, 'subsample': 0.8469973700151547}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3827929474218992, 'gamma': 0.689487650593469, 'learning_rate': 0.08940823468596758, 'max_depth': 12.0, 'min_child_samples': 20.0, 'n_estimators': 675.0, 'subsample': 0.8749809582628816}
# Accuracy Score 0.767 params {'colsample_bytree': 0.44701149003921725, 'gamma': 0.5178383507427162, 'learning_rate': 0.041203320546762484, 'max_depth': 18.0, 'min_child_samples': 18.0, 'n_estimators': 375.0, 'subsample': 0.8624458262463129}
# Accuracy Score 0.833 params {'colsample_bytree': 0.5493705625190249, 'gamma': 0.9081999514089447, 'learning_rate': 0.15533855566970708, 'max_depth': 7.0, 'min_child_samples': 12.0, 'n_estimators': 750.0, 'subsample': 0.8495741308178867}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5994074276971004, 'gamma': 0.9008168858547221, 'learning_rate': 0.14843399841065616, 'max_depth': 7.0, 'min_child_samples': 12.0, 'n_estimators': 750.0, 'subsample': 0.9170342775537041}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7289200336924082, 'gamma': 0.2761293868423458, 'learning_rate': 0.08590042699970986, 'max_depth': 4.0, 'min_child_samples': 19.0, 'n_estimators': 1000.0, 'subsample': 0.9393409298845892}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5699044535833089, 'gamma': 0.7662854505248321, 'learning_rate': 0.022339615577123748, 'max_depth': 10.0, 'min_child_samples': 13.0, 'n_estimators': 600.0, 'subsample': 0.8416022722693038}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8460907975355308, 'gamma': 0.6366127406518112, 'learning_rate': 0.01119792602180013, 'max_depth': 7.0, 'min_child_samples': 17.0, 'n_estimators': 750.0, 'subsample': 0.8620848262263139}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5288076859593517, 'gamma': 0.640552924171646, 'learning_rate': 0.03942148728672224, 'max_depth': 13.0, 'min_child_samples': 9.0, 'n_estimators': 925.0, 'subsample': 0.88642912571295}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6266395302677457, 'gamma': 0.9050122939205668, 'learning_rate': 0.116026808582908, 'max_depth': 5.0, 'min_child_samples': 11.0, 'n_estimators': 925.0, 'subsample': 0.8210779170763386}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5714468286254123, 'gamma': 0.3624381935131269, 'learning_rate': 0.07179012123167247, 'max_depth': 11.0, 'min_child_samples': 16.0, 'n_estimators': 700.0, 'subsample': 0.9108673208374283}
# Accuracy Score 0.833 params {'colsample_bytree': 0.3465085569148042, 'gamma': 0.008402456869550268, 'learning_rate': 0.13768175894079893, 'max_depth': 3.0, 'min_child_samples': 14.0, 'n_estimators': 600.0, 'subsample': 0.8669008911698649}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4708052560206564, 'gamma': 0.232660377058668, 'learning_rate': 0.10321661967732387, 'max_depth': 7.0, 'min_child_samples': 13.0, 'n_estimators': 800.0, 'subsample': 0.8907497640883467}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6966348125966899, 'gamma': 0.49383249432754944, 'learning_rate': 0.017780452735907795, 'max_depth': 9.0, 'min_child_samples': 16.0, 'n_estimators': 875.0, 'subsample': 0.9494960336761799}
# Accuracy Score 0.733 params {'colsample_bytree': 0.9027491867137484, 'gamma': 0.4385224647261181, 'learning_rate': 0.04902797716137574, 'max_depth': 12.0, 'min_child_samples': 19.0, 'n_estimators': 975.0, 'subsample': 0.8125718181758167}
# Accuracy Score 0.767 params {'colsample_bytree': 0.35195819244979737, 'gamma': 0.001308937398381233, 'learning_rate': 0.008874237532656723, 'max_depth': 18.0, 'min_child_samples': 14.0, 'n_estimators': 500.0, 'subsample': 0.8716129384504177}
# Accuracy Score 0.733 params {'colsample_bytree': 0.33899901707767127, 'gamma': 0.1851625398978728, 'learning_rate': 0.12853664915940793, 'max_depth': 3.0, 'min_child_samples': 18.0, 'n_estimators': 575.0, 'subsample': 0.9043321408776265}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3885176903549563, 'gamma': 0.06740398745613457, 'learning_rate': 0.06159356083362071, 'max_depth': 4.0, 'min_child_samples': 15.0, 'n_estimators': 625.0, 'subsample': 0.9944616519514755}
# Accuracy Score 0.767 params {'colsample_bytree': 0.9994407987868633, 'gamma': 0.00499872121885196, 'learning_rate': 0.027082486925551433, 'max_depth': 3.0, 'min_child_samples': 17.0, 'n_estimators': 425.0, 'subsample': 0.8665668101930771}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8277906046009329, 'gamma': 0.39167191528055173, 'learning_rate': 0.03452730051275102, 'max_depth': 15.0, 'min_child_samples': 20.0, 'n_estimators': 700.0, 'subsample': 0.9350299425597818}
# Accuracy Score 0.767 params {'colsample_bytree': 0.774037365788736, 'gamma': 0.5298203915355029, 'learning_rate': 0.07986823327873999, 'max_depth': 5.0, 'min_child_samples': 11.0, 'n_estimators': 475.0, 'subsample': 0.8845278454065139}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7624023733159665, 'gamma': 0.12517939462593589, 'learning_rate': 0.10264899695115363, 'max_depth': 14.0, 'min_child_samples': 13.0, 'n_estimators': 525.0, 'subsample': 0.8367221331931024}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5387342269303643, 'gamma': 0.599060702482677, 'learning_rate': 0.1642414577941577, 'max_depth': 6.0, 'min_child_samples': 5.0, 'n_estimators': 750.0, 'subsample': 0.8540835080822777}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6557736340158958, 'gamma': 0.7726065171844836, 'learning_rate': 0.1626727494043834, 'max_depth': 11.0, 'min_child_samples': 9.0, 'n_estimators': 225.0, 'subsample': 0.8194008133923045}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5991651007278616, 'gamma': 0.9370958116549745, 'learning_rate': 0.023424257947153256, 'max_depth': 13.0, 'min_child_samples': 7.0, 'n_estimators': 850.0, 'subsample': 0.8031118928814106}
# Accuracy Score 0.767 params {'colsample_bytree': 0.31825313929738624, 'gamma': 0.3094971602961203, 'learning_rate': 0.06371204222543675, 'max_depth': 17.0, 'min_child_samples': 15.0, 'n_estimators': 325.0, 'subsample': 0.9230019871132922}
# Accuracy Score 0.767 params {'colsample_bytree': 0.903448352854392, 'gamma': 0.19998832678177283, 'learning_rate': 0.12595521309459187, 'max_depth': 2.0, 'min_child_samples': 19.0, 'n_estimators': 550.0, 'subsample': 0.8795700900614506}
# Accuracy Score 0.767 params {'colsample_bytree': 0.302189807059856, 'gamma': 0.4627774561488162, 'learning_rate': 0.014800804965503962, 'max_depth': 20.0, 'min_child_samples': 16.0, 'n_estimators': 425.0, 'subsample': 0.9007872373039182}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6936527556323336, 'gamma': 0.5970220838223157, 'learning_rate': 0.0520461665750761, 'max_depth': 4.0, 'min_child_samples': 14.0, 'n_estimators': 650.0, 'subsample': 0.8282341915858024}
# Accuracy Score 0.833 params {'colsample_bytree': 0.45751606775813564, 'gamma': 0.4046804803748768, 'learning_rate': 0.1004191414683884, 'max_depth': 15.0, 'min_child_samples': 17.0, 'n_estimators': 75.0, 'subsample': 0.8933903991690195}
# Accuracy Score 0.733 params {'colsample_bytree': 0.5089520798361156, 'gamma': 0.6674459960750291, 'learning_rate': 0.14240642905091233, 'max_depth': 8.0, 'min_child_samples': 19.0, 'n_estimators': 475.0, 'subsample': 0.9495329583972215}
# Accuracy Score 0.733 params {'colsample_bytree': 0.7412556262798632, 'gamma': 0.3407399766819952, 'learning_rate': 0.034370325954611786, 'max_depth': 10.0, 'min_child_samples': 16.0, 'n_estimators': 375.0, 'subsample': 0.9767372017786765}
# Accuracy Score 0.767 params {'colsample_bytree': 0.36182404942160723, 'gamma': 0.12249405298966888, 'learning_rate': 0.006903293333437363, 'max_depth': 5.0, 'min_child_samples': 18.0, 'n_estimators': 300.0, 'subsample': 0.858787281163705}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6322408682089646, 'gamma': 0.23217062466237953, 'learning_rate': 0.04429274098633495, 'max_depth': 16.0, 'min_child_samples': 14.0, 'n_estimators': 575.0, 'subsample': 0.8435988605757886}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4486578755166577, 'gamma': 0.41524739809749783, 'learning_rate': 0.09797002891477735, 'max_depth': 19.0, 'min_child_samples': 17.0, 'n_estimators': 75.0, 'subsample': 0.9094943814588442}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4844693261233408, 'gamma': 0.5404645384019423, 'learning_rate': 0.174214811854558, 'max_depth': 15.0, 'min_child_samples': 20.0, 'n_estimators': 175.0, 'subsample': 0.8956676481592953}
# Accuracy Score 0.800 params {'colsample_bytree': 0.39623506098989275, 'gamma': 0.7403827901620279, 'learning_rate': 0.07500295659124459, 'max_depth': 13.0, 'min_child_samples': 19.0, 'n_estimators': 150.0, 'subsample': 0.9229821403705335}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6077385860283575, 'gamma': 0.5718814954298138, 'learning_rate': 0.05787267331213266, 'max_depth': 17.0, 'min_child_samples': 1.0, 'n_estimators': 100.0, 'subsample': 0.9438824134548712}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5551493443882767, 'gamma': 0.49248144091286883, 'learning_rate': 0.11091870032034816, 'max_depth': 9.0, 'min_child_samples': 6.0, 'n_estimators': 875.0, 'subsample': 0.8348792352772454}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6597841456779852, 'gamma': 0.7941228367190922, 'learning_rate': 0.1490170037916893, 'max_depth': 7.0, 'min_child_samples': 10.0, 'n_estimators': 700.0, 'subsample': 0.8692859705867985}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5204024620906214, 'gamma': 0.8567375761977148, 'learning_rate': 0.1969325912928476, 'max_depth': 6.0, 'min_child_samples': 11.0, 'n_estimators': 800.0, 'subsample': 0.8485242631559833}
# Accuracy Score 0.767 params {'colsample_bytree': 0.45488923869820796, 'gamma': 0.43553043329209495, 'learning_rate': 0.08895723659001387, 'max_depth': 14.0, 'min_child_samples': 17.0, 'n_estimators': 400.0, 'subsample': 0.8901309970852033}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4089312388649835, 'gamma': 0.8868944838500497, 'learning_rate': 0.19549475003741743, 'max_depth': 3.0, 'min_child_samples': 12.0, 'n_estimators': 625.0, 'subsample': 0.8571963301520451}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5766618957056168, 'gamma': 0.6225163037090209, 'learning_rate': 0.11895438106264519, 'max_depth': 8.0, 'min_child_samples': 9.0, 'n_estimators': 725.0, 'subsample': 0.8778129363122741}
# Accuracy Score 0.767 params {'colsample_bytree': 0.43581697246115647, 'gamma': 0.045995154548102934, 'learning_rate': 0.09770762372603763, 'max_depth': 19.0, 'min_child_samples': 13.0, 'n_estimators': 250.0, 'subsample': 0.9288212402347136}
# Accuracy Score 0.833 params {'colsample_bytree': 0.7116065282092408, 'gamma': 0.9891549511117823, 'learning_rate': 0.13670017694063086, 'max_depth': 6.0, 'min_child_samples': 15.0, 'n_estimators': 650.0, 'subsample': 0.8128036750819279}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3287087984536464, 'gamma': 0.15501989933150914, 'learning_rate': 0.07919993721703433, 'max_depth': 17.0, 'min_child_samples': 18.0, 'n_estimators': 500.0, 'subsample': 0.9117733751715366}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4977967828377058, 'gamma': 0.8277458614263052, 'learning_rate': 0.06925149424404727, 'max_depth': 10.0, 'min_child_samples': 11.0, 'n_estimators': 800.0, 'subsample': 0.8469819748864755}
# Accuracy Score 0.733 params {'colsample_bytree': 0.809764331914026, 'gamma': 0.996424536843665, 'learning_rate': 0.12811209431553972, 'max_depth': 9.0, 'min_child_samples': 18.0, 'n_estimators': 650.0, 'subsample': 0.811181565717109}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6804980375740883, 'gamma': 0.2901426798400022, 'learning_rate': 0.11919715682226296, 'max_depth': 12.0, 'min_child_samples': 16.0, 'n_estimators': 900.0, 'subsample': 0.8163633203472692}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7473464143110256, 'gamma': 0.396266078518741, 'learning_rate': 0.047904516143948965, 'max_depth': 11.0, 'min_child_samples': 15.0, 'n_estimators': 50.0, 'subsample': 0.8049197914765258}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7071819703964272, 'gamma': 0.34420320079126954, 'learning_rate': 0.16964040592639607, 'max_depth': 6.0, 'min_child_samples': 15.0, 'n_estimators': 325.0, 'subsample': 0.9175054755675841}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7171051030432996, 'gamma': 0.2333818831322763, 'learning_rate': 0.03692261568505999, 'max_depth': 15.0, 'min_child_samples': 20.0, 'n_estimators': 975.0, 'subsample': 0.8254853395982712}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6193758673089429, 'gamma': 0.9423594109785303, 'learning_rate': 0.05572967793828197, 'max_depth': 12.0, 'min_child_samples': 17.0, 'n_estimators': 450.0, 'subsample': 0.8328069690303177}
# Accuracy Score 0.800 params {'colsample_bytree': 0.8710524609395482, 'gamma': 0.996234364928711, 'learning_rate': 0.1566895292463023, 'max_depth': 8.0, 'min_child_samples': 10.0, 'n_estimators': 775.0, 'subsample': 0.8412662654465669}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7925406926091253, 'gamma': 0.5056293799908718, 'learning_rate': 0.030402404235535876, 'max_depth': 14.0, 'min_child_samples': 20.0, 'n_estimators': 550.0, 'subsample': 0.8816692879687166}
# Accuracy Score 0.733 params {'colsample_bytree': 0.30099568074474176, 'gamma': 0.6637942586460062, 'learning_rate': 0.09298248705758126, 'max_depth': 16.0, 'min_child_samples': 14.0, 'n_estimators': 225.0, 'subsample': 0.8724099314552188}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6482199421306272, 'gamma': 0.924618434165945, 'learning_rate': 0.18046052157592896, 'max_depth': 7.0, 'min_child_samples': 8.0, 'n_estimators': 825.0, 'subsample': 0.8235936395616599}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5421278955726366, 'gamma': 0.7397787796723623, 'learning_rate': 0.0823244194451055, 'max_depth': 5.0, 'min_child_samples': 4.0, 'n_estimators': 600.0, 'subsample': 0.8619421042837128}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3684476578142104, 'gamma': 0.9660462318503422, 'learning_rate': 0.10830922536616243, 'max_depth': 4.0, 'min_child_samples': 12.0, 'n_estimators': 675.0, 'subsample': 0.8665394036651811}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4798207678126183, 'gamma': 0.8047064014230071, 'learning_rate': 0.19940686893321782, 'max_depth': 3.0, 'min_child_samples': 13.0, 'n_estimators': 500.0, 'subsample': 0.8533012155018486}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5897640013047011, 'gamma': 0.08614298731500784, 'learning_rate': 0.06625317816186951, 'max_depth': 7.0, 'min_child_samples': 7.0, 'n_estimators': 575.0, 'subsample': 0.8873731578937077}
# Accuracy Score 0.767 params {'colsample_bytree': 0.46803688195276977, 'gamma': 0.020517025000023503, 'learning_rate': 0.017978188082273618, 'max_depth': 16.0, 'min_child_samples': 18.0, 'n_estimators': 400.0, 'subsample': 0.9025714806070272}
# Accuracy Score 0.733 params {'colsample_bytree': 0.5474230872072859, 'gamma': 0.36406038642193694, 'learning_rate': 0.045521319684494285, 'max_depth': 9.0, 'min_child_samples': 19.0, 'n_estimators': 125.0, 'subsample': 0.8929941816225406}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6709201305357491, 'gamma': 0.7098144414159966, 'learning_rate': 0.14030134986464513, 'max_depth': 5.0, 'min_child_samples': 8.0, 'n_estimators': 725.0, 'subsample': 0.8761445278110702}
# Accuracy Score 0.767 params {'colsample_bytree': 0.34616437500202757, 'gamma': 0.4719717784105364, 'learning_rate': 0.07196180337994611, 'max_depth': 14.0, 'min_child_samples': 16.0, 'n_estimators': 450.0, 'subsample': 0.9087453387747092}
# Accuracy Score 0.767 params {'colsample_bytree': 0.40058802877322847, 'gamma': 0.6182118263036198, 'learning_rate': 0.02440497599320885, 'max_depth': 19.0, 'min_child_samples': 17.0, 'n_estimators': 300.0, 'subsample': 0.8981242005579521}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3787945708788848, 'gamma': 0.24976691343647583, 'learning_rate': 0.0050087957145937365, 'max_depth': 2.0, 'min_child_samples': 13.0, 'n_estimators': 275.0, 'subsample': 0.9152975917946697}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4311270265493224, 'gamma': 0.5515794127292355, 'learning_rate': 0.012752749743824439, 'max_depth': 18.0, 'min_child_samples': 16.0, 'n_estimators': 200.0, 'subsample': 0.8824817834125687}
# Accuracy Score 0.767 params {'colsample_bytree': 0.41102633319844506, 'gamma': 0.5745356612903469, 'learning_rate': 0.09930364673522868, 'max_depth': 13.0, 'min_child_samples': 14.0, 'n_estimators': 350.0, 'subsample': 0.9733729071186261}
# Accuracy Score 0.733 params {'colsample_bytree': 0.5240336492062306, 'gamma': 0.1467510677411176, 'learning_rate': 0.00948254395968816, 'max_depth': 20.0, 'min_child_samples': 19.0, 'n_estimators': 525.0, 'subsample': 0.9307399160292955}
# Accuracy Score 0.767 params {'colsample_bytree': 0.49918465819728686, 'gamma': 0.31244042813168055, 'learning_rate': 0.06302125750421138, 'max_depth': 15.0, 'min_child_samples': 15.0, 'n_estimators': 625.0, 'subsample': 0.8569173225471073}
# Accuracy Score 0.733 params {'colsample_bytree': 0.8250302154679501, 'gamma': 0.1926737687994618, 'learning_rate': 0.13541608145812542, 'max_depth': 11.0, 'min_child_samples': 15.0, 'n_estimators': 950.0, 'subsample': 0.9908172738089404}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7721575691865867, 'gamma': 0.6767854520185055, 'learning_rate': 0.11143431408963787, 'max_depth': 10.0, 'min_child_samples': 2.0, 'n_estimators': 775.0, 'subsample': 0.9542044206062521}
# Accuracy Score 0.767 params {'colsample_bytree': 0.45880646315473667, 'gamma': 0.38142921314457157, 'learning_rate': 0.019974783052717292, 'max_depth': 12.0, 'min_child_samples': 17.0, 'n_estimators': 675.0, 'subsample': 0.8674082510513857}
# Accuracy Score 0.733 params {'colsample_bytree': 0.36118869650622665, 'gamma': 0.42140471197461393, 'learning_rate': 0.1487288722510131, 'max_depth': 13.0, 'min_child_samples': 18.0, 'n_estimators': 475.0, 'subsample': 0.9379454101456423}
# Accuracy Score 0.767 params {'colsample_bytree': 0.968093338675035, 'gamma': 0.7703249670769343, 'learning_rate': 0.12360885772548504, 'max_depth': 10.0, 'min_child_samples': 20.0, 'n_estimators': 725.0, 'subsample': 0.8397631867704676}
# Accuracy Score 0.767 params {'colsample_bytree': 0.9259822693293327, 'gamma': 0.28194476334671204, 'learning_rate': 0.05270065014948642, 'max_depth': 8.0, 'min_child_samples': 19.0, 'n_estimators': 875.0, 'subsample': 0.8102164228850973}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3273399553811982, 'gamma': 0.4434410927525826, 'learning_rate': 0.17436310663989674, 'max_depth': 17.0, 'min_child_samples': 13.0, 'n_estimators': 75.0, 'subsample': 0.9259588638062}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5607584805082568, 'gamma': 0.6534356932670852, 'learning_rate': 0.07687528228976812, 'max_depth': 18.0, 'min_child_samples': 14.0, 'n_estimators': 400.0, 'subsample': 0.8453630101704248}
# Accuracy Score 0.800 params {'colsample_bytree': 0.587835672088995, 'gamma': 0.8816430345454197, 'learning_rate': 0.08441437531185775, 'max_depth': 6.0, 'min_child_samples': 17.0, 'n_estimators': 825.0, 'subsample': 0.8317207630422333}
# Accuracy Score 0.733 params {'colsample_bytree': 0.7508885929597473, 'gamma': 0.9633186340133355, 'learning_rate': 0.1847281289532721, 'max_depth': 4.0, 'min_child_samples': 12.0, 'n_estimators': 550.0, 'subsample': 0.8001683693029431}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6167101349577013, 'gamma': 0.4683172751744882, 'learning_rate': 0.03956178825650647, 'max_depth': 15.0, 'min_child_samples': 16.0, 'n_estimators': 125.0, 'subsample': 0.8740116551752397}
# Accuracy Score 0.800 params {'colsample_bytree': 0.43104568398942245, 'gamma': 0.5249116207076601, 'learning_rate': 0.05933116047718823, 'max_depth': 2.0, 'min_child_samples': 18.0, 'n_estimators': 600.0, 'subsample': 0.850665394622527}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6413418762149917, 'gamma': 0.8370943357503314, 'learning_rate': 0.16143472455305477, 'max_depth': 9.0, 'min_child_samples': 9.0, 'n_estimators': 700.0, 'subsample': 0.8170502707564951}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5159735323747117, 'gamma': 0.09543505300597177, 'learning_rate': 0.10574762033272157, 'max_depth': 13.0, 'min_child_samples': 10.0, 'n_estimators': 325.0, 'subsample': 0.8886923057694474}
# Accuracy Score 0.767 params {'colsample_bytree': 0.853355737566359, 'gamma': 0.21119807735136675, 'learning_rate': 0.13126104877635572, 'max_depth': 6.0, 'min_child_samples': 15.0, 'n_estimators': 650.0, 'subsample': 0.8273128716700435}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8831387012800213, 'gamma': 0.056261399455399985, 'learning_rate': 0.09442614790768568, 'max_depth': 3.0, 'min_child_samples': 11.0, 'n_estimators': 500.0, 'subsample': 0.8594602346677288}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7256557436458991, 'gamma': 0.7176163132909964, 'learning_rate': 0.0256474492749044, 'max_depth': 4.0, 'min_child_samples': 12.0, 'n_estimators': 625.0, 'subsample': 0.8059809049867197}
# Accuracy Score 0.800 params {'colsample_bytree': 0.8258759778987053, 'gamma': 0.751093799530395, 'learning_rate': 0.14255633063307488, 'max_depth': 5.0, 'min_child_samples': 14.0, 'n_estimators': 425.0, 'subsample': 0.8140711556883187}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6985121629331745, 'gamma': 0.1718169055741936, 'learning_rate': 0.15466172555882737, 'max_depth': 7.0, 'min_child_samples': 6.0, 'n_estimators': 750.0, 'subsample': 0.8366630125156345}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6802863024344075, 'gamma': 0.3149698483083241, 'learning_rate': 0.11600067645224033, 'max_depth': 11.0, 'min_child_samples': 20.0, 'n_estimators': 175.0, 'subsample': 0.9064234188432216}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5749529612861004, 'gamma': 0.6898002495127805, 'learning_rate': 0.031529522108604636, 'max_depth': 10.0, 'min_child_samples': 2.0, 'n_estimators': 900.0, 'subsample': 0.9200918314327631}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5336129051119775, 'gamma': 0.621831772259328, 'learning_rate': 0.06707599439509009, 'max_depth': 9.0, 'min_child_samples': 4.0, 'n_estimators': 900.0, 'subsample': 0.8803279598056607}
# Accuracy Score 0.733 params {'colsample_bytree': 0.4892650943822772, 'gamma': 0.3654562012694927, 'learning_rate': 0.19904107673108737, 'max_depth': 8.0, 'min_child_samples': 10.0, 'n_estimators': 1000.0, 'subsample': 0.8931220709460052}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6062855331924035, 'gamma': 0.9182854514319247, 'learning_rate': 0.007395620913997069, 'max_depth': 7.0, 'min_child_samples': 8.0, 'n_estimators': 850.0, 'subsample': 0.8641422206778928}
# Accuracy Score 0.733 params {'colsample_bytree': 0.7112343621936357, 'gamma': 0.48945755639518895, 'learning_rate': 0.085426603609047, 'max_depth': 12.0, 'min_child_samples': 18.0, 'n_estimators': 275.0, 'subsample': 0.9590905906019701}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6286855143042278, 'gamma': 0.2607649464103222, 'learning_rate': 0.036372933625148804, 'max_depth': 14.0, 'min_child_samples': 16.0, 'n_estimators': 225.0, 'subsample': 0.9447620520886264}
# Accuracy Score 0.833 params {'colsample_bytree': 0.6661066186310479, 'gamma': 0.02737767395533619, 'learning_rate': 0.16743950409977704, 'max_depth': 2.0, 'min_child_samples': 7.0, 'n_estimators': 575.0, 'subsample': 0.8410425706359246}
# Accuracy Score 0.733 params {'colsample_bytree': 0.7818453040218575, 'gamma': 0.41752907279105567, 'learning_rate': 0.028853659546699523, 'max_depth': 6.0, 'min_child_samples': 19.0, 'n_estimators': 375.0, 'subsample': 0.912869801856519}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3062101910762649, 'gamma': 0.8833397158470399, 'learning_rate': 0.01490319593702045, 'max_depth': 8.0, 'min_child_samples': 11.0, 'n_estimators': 775.0, 'subsample': 0.8702875515110563}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6504641896010928, 'gamma': 0.8552837423185082, 'learning_rate': 0.17823299053469335, 'max_depth': 2.0, 'min_child_samples': 3.0, 'n_estimators': 675.0, 'subsample': 0.8220443585213018}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6646172977474392, 'gamma': 0.575185876508836, 'learning_rate': 0.020898511796982253, 'max_depth': 18.0, 'min_child_samples': 5.0, 'n_estimators': 575.0, 'subsample': 0.9002729618001473}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8021443175021755, 'gamma': 0.023194919011845394, 'learning_rate': 0.04775351881932406, 'max_depth': 16.0, 'min_child_samples': 6.0, 'n_estimators': 250.0, 'subsample': 0.8395873115572104}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5876854766031427, 'gamma': 0.6039053195822714, 'learning_rate': 0.10322255920795127, 'max_depth': 19.0, 'min_child_samples': 7.0, 'n_estimators': 450.0, 'subsample': 0.8510508428978284}
# Accuracy Score 0.733 params {'colsample_bytree': 0.7363187719776525, 'gamma': 0.8254912977414113, 'learning_rate': 0.0914314134329236, 'max_depth': 3.0, 'min_child_samples': 9.0, 'n_estimators': 475.0, 'subsample': 0.833987420780331}
# Accuracy Score 0.800 params {'colsample_bytree': 0.7524566869157617, 'gamma': 0.3402664812352523, 'learning_rate': 0.0415780956549699, 'max_depth': 17.0, 'min_child_samples': 5.0, 'n_estimators': 50.0, 'subsample': 0.885507246501866}
# Accuracy Score 0.833 params {'colsample_bytree': 0.5502876919462241, 'gamma': 0.7810493604668193, 'learning_rate': 0.16530905627568204, 'max_depth': 4.0, 'min_child_samples': 4.0, 'n_estimators': 550.0, 'subsample': 0.8609428890446519}
# Accuracy Score 0.767 params {'colsample_bytree': 0.722741746572895, 'gamma': 0.9507749501888496, 'learning_rate': 0.055375046312504984, 'max_depth': 5.0, 'min_child_samples': 9.0, 'n_estimators': 525.0, 'subsample': 0.818610159283968}
# Accuracy Score 0.767 params {'colsample_bytree': 0.47036963520182795, 'gamma': 0.6420232689370586, 'learning_rate': 0.19895034665622607, 'max_depth': 6.0, 'min_child_samples': 13.0, 'n_estimators': 600.0, 'subsample': 0.8465744364655781}
# Accuracy Score 0.767 params {'colsample_bytree': 0.505285625286181, 'gamma': 0.7989183688711874, 'learning_rate': 0.010387567058481073, 'max_depth': 7.0, 'min_child_samples': 12.0, 'n_estimators': 800.0, 'subsample': 0.8561386672326445}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6386021031956721, 'gamma': 0.7872090037090476, 'learning_rate': 0.12964544929700586, 'max_depth': 4.0, 'min_child_samples': 4.0, 'n_estimators': 500.0, 'subsample': 0.8625166167715681}
# Accuracy Score 0.800 params {'colsample_bytree': 0.9910740271998448, 'gamma': 0.9895261107695605, 'learning_rate': 0.11822491331173071, 'max_depth': 4.0, 'min_child_samples': 3.0, 'n_estimators': 550.0, 'subsample': 0.8296161727777344}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5571757076964865, 'gamma': 0.7262412232277767, 'learning_rate': 0.012935164992737254, 'max_depth': 9.0, 'min_child_samples': 3.0, 'n_estimators': 725.0, 'subsample': 0.8773029049860569}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5365130091149521, 'gamma': 0.6883372377833258, 'learning_rate': 0.15273627925095093, 'max_depth': 5.0, 'min_child_samples': 6.0, 'n_estimators': 625.0, 'subsample': 0.8711254495056769}
# Accuracy Score 0.767 params {'colsample_bytree': 0.388190771176446, 'gamma': 0.1341929365422912, 'learning_rate': 0.07225751549274426, 'max_depth': 11.0, 'min_child_samples': 13.0, 'n_estimators': 825.0, 'subsample': 0.8518436154263883}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7664555181148996, 'gamma': 0.9021214879129287, 'learning_rate': 0.007827817748916313, 'max_depth': 8.0, 'min_child_samples': 7.0, 'n_estimators': 700.0, 'subsample': 0.8435960176644204}
# Accuracy Score 0.800 params {'colsample_bytree': 0.6998664567728399, 'gamma': 0.1038656869767908, 'learning_rate': 0.18858879790614413, 'max_depth': 7.0, 'min_child_samples': 7.0, 'n_estimators': 350.0, 'subsample': 0.8242555380002041}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5969453851044043, 'gamma': 0.5448949127302692, 'learning_rate': 0.16244188142259006, 'max_depth': 3.0, 'min_child_samples': 2.0, 'n_estimators': 575.0, 'subsample': 0.8598484817167317}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4433544374506752, 'gamma': 0.519786178290984, 'learning_rate': 0.1683425713173656, 'max_depth': 14.0, 'min_child_samples': 1.0, 'n_estimators': 425.0, 'subsample': 0.8946195588788988}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3535197409241418, 'gamma': 0.39123038710141195, 'learning_rate': 0.11097545094133147, 'max_depth': 10.0, 'min_child_samples': 14.0, 'n_estimators': 975.0, 'subsample': 0.8663336367997057}
# Accuracy Score 0.800 params {'colsample_bytree': 0.42335735618388687, 'gamma': 0.7586008404716196, 'learning_rate': 0.1451262096619391, 'max_depth': 12.0, 'min_child_samples': 17.0, 'n_estimators': 750.0, 'subsample': 0.9042807131413587}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5721863580233013, 'gamma': 0.8570082597925937, 'learning_rate': 0.13984926603827294, 'max_depth': 3.0, 'min_child_samples': 10.0, 'n_estimators': 525.0, 'subsample': 0.8484100335787408}
# Accuracy Score 0.800 params {'colsample_bytree': 0.40610917496189725, 'gamma': 0.5609540864573612, 'learning_rate': 0.07915777068330944, 'max_depth': 2.0, 'min_child_samples': 17.0, 'n_estimators': 300.0, 'subsample': 0.8974607386504511}
# Accuracy Score 0.800 params {'colsample_bytree': 0.3355957092421198, 'gamma': 0.582458252644392, 'learning_rate': 0.12803078252191002, 'max_depth': 15.0, 'min_child_samples': 15.0, 'n_estimators': 475.0, 'subsample': 0.8835668293348287}
# Accuracy Score 0.800 params {'colsample_bytree': 0.45721413192815574, 'gamma': 0.004150618876789469, 'learning_rate': 0.09815278080456401, 'max_depth': 5.0, 'min_child_samples': 16.0, 'n_estimators': 700.0, 'subsample': 0.8912269218679723}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3747353008646813, 'gamma': 0.2118722228272926, 'learning_rate': 0.0862598098544148, 'max_depth': 6.0, 'min_child_samples': 15.0, 'n_estimators': 100.0, 'subsample': 0.8009761216491558}
# Accuracy Score 0.733 params {'colsample_bytree': 0.686005024247432, 'gamma': 0.9744084310782923, 'learning_rate': 0.11756227181978164, 'max_depth': 9.0, 'min_child_samples': 16.0, 'n_estimators': 650.0, 'subsample': 0.874002949854981}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6662848933928355, 'gamma': 0.07095241229276594, 'learning_rate': 0.06272865632939957, 'max_depth': 11.0, 'min_child_samples': 18.0, 'n_estimators': 650.0, 'subsample': 0.813621780596626}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7884587138354106, 'gamma': 0.297722054935181, 'learning_rate': 0.19627113262378854, 'max_depth': 10.0, 'min_child_samples': 20.0, 'n_estimators': 400.0, 'subsample': 0.842465800532414}
# Accuracy Score 0.800 params {'colsample_bytree': 0.8426796230142144, 'gamma': 0.17720309896156494, 'learning_rate': 0.1802655280176681, 'max_depth': 8.0, 'min_child_samples': 20.0, 'n_estimators': 675.0, 'subsample': 0.8055619285812089}
# Accuracy Score 0.767 params {'colsample_bytree': 0.9313698974376513, 'gamma': 0.2402220412285359, 'learning_rate': 0.13365124664454225, 'max_depth': 7.0, 'min_child_samples': 14.0, 'n_estimators': 775.0, 'subsample': 0.9337437928748089}
# Accuracy Score 0.800 params {'colsample_bytree': 0.6250570477051651, 'gamma': 0.4595198257741344, 'learning_rate': 0.1034573642953592, 'max_depth': 9.0, 'min_child_samples': 12.0, 'n_estimators': 750.0, 'subsample': 0.8353494093816675}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4839738517562895, 'gamma': 0.26786795737121233, 'learning_rate': 0.07664844043882806, 'max_depth': 6.0, 'min_child_samples': 18.0, 'n_estimators': 625.0, 'subsample': 0.9078532696061974}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3189242952198161, 'gamma': 0.11484262801450361, 'learning_rate': 0.09505180735021199, 'max_depth': 5.0, 'min_child_samples': 15.0, 'n_estimators': 600.0, 'subsample': 0.879458953664116}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3431285414264115, 'gamma': 0.21670943304112308, 'learning_rate': 0.05052789881233361, 'max_depth': 13.0, 'min_child_samples': 19.0, 'n_estimators': 350.0, 'subsample': 0.9189631218507041}
# Accuracy Score 0.800 params {'colsample_bytree': 0.3863584883906117, 'gamma': 0.48761603178732604, 'learning_rate': 0.10779988663525449, 'max_depth': 10.0, 'min_child_samples': 17.0, 'n_estimators': 200.0, 'subsample': 0.913213976739984}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4131979364427155, 'gamma': 0.1605451930772895, 'learning_rate': 0.01690406626445143, 'max_depth': 20.0, 'min_child_samples': 14.0, 'n_estimators': 850.0, 'subsample': 0.8867547450072251}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5496223318296175, 'gamma': 0.8183982782611565, 'learning_rate': 0.15761105260571925, 'max_depth': 12.0, 'min_child_samples': 19.0, 'n_estimators': 950.0, 'subsample': 0.8646735864768456}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6198330476679279, 'gamma': 0.32696685865382324, 'learning_rate': 0.17348730875333143, 'max_depth': 11.0, 'min_child_samples': 8.0, 'n_estimators': 925.0, 'subsample': 0.8537415151492789}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5195421368003281, 'gamma': 0.9290951242120037, 'learning_rate': 0.14947993161057474, 'max_depth': 8.0, 'min_child_samples': 4.0, 'n_estimators': 450.0, 'subsample': 0.8566423109206177}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4966454771843633, 'gamma': 0.3667908182056211, 'learning_rate': 0.12151366741821792, 'max_depth': 7.0, 'min_child_samples': 11.0, 'n_estimators': 875.0, 'subsample': 0.8308703991231283}
# Accuracy Score 0.733 params {'colsample_bytree': 0.8948403006430667, 'gamma': 0.9137329922173907, 'learning_rate': 0.1988370504720332, 'max_depth': 6.0, 'min_child_samples': 13.0, 'n_estimators': 725.0, 'subsample': 0.8216074288031571}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7119040960393885, 'gamma': 0.993357924315984, 'learning_rate': 0.006205998888686036, 'max_depth': 4.0, 'min_child_samples': 12.0, 'n_estimators': 675.0, 'subsample': 0.8255468307910068}
# Accuracy Score 0.733 params {'colsample_bytree': 0.8166627808103758, 'gamma': 0.4351786590865747, 'learning_rate': 0.08779550406914484, 'max_depth': 13.0, 'min_child_samples': 8.0, 'n_estimators': 550.0, 'subsample': 0.8393534709528601}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7586906837211089, 'gamma': 0.04729610550723573, 'learning_rate': 0.06843912211866028, 'max_depth': 16.0, 'min_child_samples': 18.0, 'n_estimators': 150.0, 'subsample': 0.8125769388619489}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6570373217087705, 'gamma': 0.02339706746025716, 'learning_rate': 0.13524807576535894, 'max_depth': 2.0, 'min_child_samples': 6.0, 'n_estimators': 375.0, 'subsample': 0.984596648324692}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6895849421173479, 'gamma': 0.13522950491351537, 'learning_rate': 0.043505469649303054, 'max_depth': 15.0, 'min_child_samples': 19.0, 'n_estimators': 575.0, 'subsample': 0.817204059436478}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5918746265961975, 'gamma': 0.6136381994216022, 'learning_rate': 0.16800202678939197, 'max_depth': 2.0, 'min_child_samples': 5.0, 'n_estimators': 475.0, 'subsample': 0.8704507089265214}
# Accuracy Score 0.833 params {'colsample_bytree': 0.7413933624927854, 'gamma': 0.7746079438491853, 'learning_rate': 0.18288291411365182, 'max_depth': 3.0, 'min_child_samples': 16.0, 'n_estimators': 500.0, 'subsample': 0.8611368403036164}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6121613808369871, 'gamma': 0.6639328125756497, 'learning_rate': 0.12430437676815283, 'max_depth': 4.0, 'min_child_samples': 2.0, 'n_estimators': 550.0, 'subsample': 0.8030737762943263}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8431981189327692, 'gamma': 0.4116358553507141, 'learning_rate': 0.05795717335746336, 'max_depth': 9.0, 'min_child_samples': 19.0, 'n_estimators': 800.0, 'subsample': 0.8074593198254788}
# Accuracy Score 0.833 params {'colsample_bytree': 0.5632540501575949, 'gamma': 0.7081727476911213, 'learning_rate': 0.11344723182318761, 'max_depth': 4.0, 'min_child_samples': 10.0, 'n_estimators': 600.0, 'subsample': 0.8472046730343129}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6728700519692485, 'gamma': 0.7890350261060652, 'learning_rate': 0.1775399913769284, 'max_depth': 3.0, 'min_child_samples': 4.0, 'n_estimators': 500.0, 'subsample': 0.8595984607666474}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5279297720380867, 'gamma': 0.6400621249404537, 'learning_rate': 0.036604508496160364, 'max_depth': 8.0, 'min_child_samples': 11.0, 'n_estimators': 950.0, 'subsample': 0.8478799021292494}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6358425399220703, 'gamma': 0.502396437724821, 'learning_rate': 0.08268503964094162, 'max_depth': 5.0, 'min_child_samples': 20.0, 'n_estimators': 425.0, 'subsample': 0.9417392863430154}
# Accuracy Score 0.800 params {'colsample_bytree': 0.46397540007319493, 'gamma': 0.7294367500102825, 'learning_rate': 0.14236461969032074, 'max_depth': 14.0, 'min_child_samples': 16.0, 'n_estimators': 250.0, 'subsample': 0.9017978598257528}
# Accuracy Score 0.800 params {'colsample_bytree': 0.868233672871527, 'gamma': 0.8808723688465433, 'learning_rate': 0.15238084361396237, 'max_depth': 5.0, 'min_child_samples': 13.0, 'n_estimators': 625.0, 'subsample': 0.8682966372566915}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5776692927017415, 'gamma': 0.4404520873315575, 'learning_rate': 0.0935450056500685, 'max_depth': 7.0, 'min_child_samples': 14.0, 'n_estimators': 775.0, 'subsample': 0.9271688141058467}
# Accuracy Score 0.767 params {'colsample_bytree': 0.9508194070737999, 'gamma': 0.9421081870085596, 'learning_rate': 0.005094836530337376, 'max_depth': 6.0, 'min_child_samples': 12.0, 'n_estimators': 825.0, 'subsample': 0.8335771945171445}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4382017268790671, 'gamma': 0.5477737678566197, 'learning_rate': 0.10324564673647164, 'max_depth': 18.0, 'min_child_samples': 1.0, 'n_estimators': 450.0, 'subsample': 0.8749454375726731}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4763721504533097, 'gamma': 0.5963752184025559, 'learning_rate': 0.03337637752564279, 'max_depth': 17.0, 'min_child_samples': 17.0, 'n_estimators': 325.0, 'subsample': 0.8830942901941369}
# Accuracy Score 0.800 params {'colsample_bytree': 0.6041733576646424, 'gamma': 0.8663290722922544, 'learning_rate': 0.07536741391282256, 'max_depth': 10.0, 'min_child_samples': 15.0, 'n_estimators': 750.0, 'subsample': 0.8285162980411496}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5134344342366188, 'gamma': 0.3496814719245034, 'learning_rate': 0.06234348612753251, 'max_depth': 9.0, 'min_child_samples': 15.0, 'n_estimators': 925.0, 'subsample': 0.87891811997761}
# Accuracy Score 0.767 params {'colsample_bytree': 0.42395587271221924, 'gamma': 0.07228155566229899, 'learning_rate': 0.19838098210181512, 'max_depth': 12.0, 'min_child_samples': 11.0, 'n_estimators': 700.0, 'subsample': 0.8978896366348188}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5595655490104424, 'gamma': 0.7106837671262398, 'learning_rate': 0.18500521591153962, 'max_depth': 4.0, 'min_child_samples': 3.0, 'n_estimators': 500.0, 'subsample': 0.8533221406023878}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3639742350897719, 'gamma': 0.6840389698583722, 'learning_rate': 0.12489195040399884, 'max_depth': 11.0, 'min_child_samples': 14.0, 'n_estimators': 875.0, 'subsample': 0.8937763295258594}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5452953020123454, 'gamma': 0.7564203043071074, 'learning_rate': 0.1886796560851959, 'max_depth': 3.0, 'min_child_samples': 9.0, 'n_estimators': 400.0, 'subsample': 0.8456889845660958}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6507175215982661, 'gamma': 0.9538096586098945, 'learning_rate': 0.05323405878378928, 'max_depth': 8.0, 'min_child_samples': 18.0, 'n_estimators': 800.0, 'subsample': 0.9234928607392682}
# Accuracy Score 0.767 params {'colsample_bytree': 0.49038777864129557, 'gamma': 0.8404963647700543, 'learning_rate': 0.11083564630153267, 'max_depth': 11.0, 'min_child_samples': 17.0, 'n_estimators': 100.0, 'subsample': 0.8629703556984499}
# Accuracy Score 0.800 params {'colsample_bytree': 0.7753901693835458, 'gamma': 0.8117799726622408, 'learning_rate': 0.16301423089415035, 'max_depth': 6.0, 'min_child_samples': 16.0, 'n_estimators': 525.0, 'subsample': 0.8089857019903083}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7302515830500964, 'gamma': 0.02837231562596143, 'learning_rate': 0.14271622315505678, 'max_depth': 2.0, 'min_child_samples': 6.0, 'n_estimators': 550.0, 'subsample': 0.8384512624559092}
# Accuracy Score 0.733 params {'colsample_bytree': 0.7964771743358899, 'gamma': 0.7697748572713289, 'learning_rate': 0.13527540206778566, 'max_depth': 3.0, 'min_child_samples': 16.0, 'n_estimators': 525.0, 'subsample': 0.8889840448725232}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5831903797364804, 'gamma': 0.11214507553594985, 'learning_rate': 0.15867526021059283, 'max_depth': 2.0, 'min_child_samples': 5.0, 'n_estimators': 475.0, 'subsample': 0.8435237957180202}
# Accuracy Score 0.733 params {'colsample_bytree': 0.701051205115842, 'gamma': 0.7395416415353747, 'learning_rate': 0.06673025172488242, 'max_depth': 3.0, 'min_child_samples': 10.0, 'n_estimators': 600.0, 'subsample': 0.8666683610064281}
# ...
# Accuracy Score 0.767 params {'colsample_bytree': 0.3750485254285091, 'gamma': 0.47342769932525103, 'learning_rate': 0.0792781122525594, 'max_depth': 14.0, 'min_child_samples': 18.0, 'n_estimators': 525.0, 'subsample': 0.8767224720654442}
# Accuracy Score 0.767 params {'colsample_bytree': 0.9925203153337093, 'gamma': 0.6012497170363125, 'learning_rate': 0.19576090504567895, 'max_depth': 2.0, 'min_child_samples': 7.0, 'n_estimators': 975.0, 'subsample': 0.9165369035514153}
# Accuracy Score 0.800 params {'colsample_bytree': 0.9098419975047133, 'gamma': 0.5692690400336211, 'learning_rate': 0.19970534969420994, 'max_depth': 2.0, 'min_child_samples': 8.0, 'n_estimators': 400.0, 'subsample': 0.8366999745471606}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8807495941402019, 'gamma': 0.6234437282106082, 'learning_rate': 0.199908909722143, 'max_depth': 2.0, 'min_child_samples': 6.0, 'n_estimators': 900.0, 'subsample': 0.9392498247613158}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3014515173412954, 'gamma': 0.6744084150355298, 'learning_rate': 0.1392626776741914, 'max_depth': 13.0, 'min_child_samples': 10.0, 'n_estimators': 375.0, 'subsample': 0.8668647461318101}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5809243903064102, 'gamma': 0.3905220320605318, 'learning_rate': 0.12932370358928041, 'max_depth': 19.0, 'min_child_samples': 20.0, 'n_estimators': 725.0, 'subsample': 0.8852847318672087}
# Accuracy Score 0.700 params {'colsample_bytree': 0.5387730130382752, 'gamma': 0.9009026771071476, 'learning_rate': 0.1693910765442724, 'max_depth': 9.0, 'min_child_samples': 12.0, 'n_estimators': 925.0, 'subsample': 0.8875257041920275}
# Accuracy Score 0.767 params {'colsample_bytree': 0.8969850426500611, 'gamma': 0.6355228475057874, 'learning_rate': 0.16057179618764206, 'max_depth': 2.0, 'min_child_samples': 7.0, 'n_estimators': 350.0, 'subsample': 0.8241461452390854}
# Accuracy Score 0.800 params {'colsample_bytree': 0.9440154299114875, 'gamma': 0.5888955984848512, 'learning_rate': 0.12012624383389878, 'max_depth': 13.0, 'min_child_samples': 9.0, 'n_estimators': 75.0, 'subsample': 0.8529510225314627}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6907092378856152, 'gamma': 0.710845195832905, 'learning_rate': 0.02082447947062859, 'max_depth': 5.0, 'min_child_samples': 5.0, 'n_estimators': 600.0, 'subsample': 0.8568785072959364}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5557096146075919, 'gamma': 0.6866668854703536, 'learning_rate': 0.18032102184932014, 'max_depth': 7.0, 'min_child_samples': 6.0, 'n_estimators': 900.0, 'subsample': 0.8490664548309751}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7075467348307645, 'gamma': 0.768720099438365, 'learning_rate': 0.10882435987328613, 'max_depth': 6.0, 'min_child_samples': 4.0, 'n_estimators': 550.0, 'subsample': 0.8425274684007857}
# Accuracy Score 0.767 params {'colsample_bytree': 0.611847972880493, 'gamma': 0.7425384903794514, 'learning_rate': 0.14807970015136052, 'max_depth': 5.0, 'min_child_samples': 1.0, 'n_estimators': 500.0, 'subsample': 0.8296117902233519}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6367135332779655, 'gamma': 0.85530810353069, 'learning_rate': 0.1726464025672605, 'max_depth': 10.0, 'min_child_samples': 12.0, 'n_estimators': 300.0, 'subsample': 0.8982368600965294}
# Accuracy Score 0.800 params {'colsample_bytree': 0.3384644919432095, 'gamma': 0.3611844868829007, 'learning_rate': 0.1380400465623062, 'max_depth': 15.0, 'min_child_samples': 13.0, 'n_estimators': 975.0, 'subsample': 0.8795850346996296}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6281640165135008, 'gamma': 0.6674783251985279, 'learning_rate': 0.19771385613426698, 'max_depth': 7.0, 'min_child_samples': 10.0, 'n_estimators': 400.0, 'subsample': 0.8624323559851128}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6836857817040128, 'gamma': 0.9371738092161941, 'learning_rate': 0.08696968359427112, 'max_depth': 7.0, 'min_child_samples': 19.0, 'n_estimators': 650.0, 'subsample': 0.8326316983342587}
# Accuracy Score 0.800 params {'colsample_bytree': 0.3169201035534605, 'gamma': 0.4548812176092037, 'learning_rate': 0.10032356258355687, 'max_depth': 17.0, 'min_child_samples': 14.0, 'n_estimators': 850.0, 'subsample': 0.8994343076621287}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4715279392722188, 'gamma': 0.2939183534663545, 'learning_rate': 0.08357477599291203, 'max_depth': 20.0, 'min_child_samples': 2.0, 'n_estimators': 750.0, 'subsample': 0.8927314158349464}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4853088730420809, 'gamma': 0.4114705523711357, 'learning_rate': 0.12657610920814738, 'max_depth': 18.0, 'min_child_samples': 3.0, 'n_estimators': 100.0, 'subsample': 0.9060991231668315}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7234751185901274, 'gamma': 0.4022457636963204, 'learning_rate': 0.16251891587153672, 'max_depth': 8.0, 'min_child_samples': 8.0, 'n_estimators': 675.0, 'subsample': 0.8016226975029707}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5086278702046204, 'gamma': 0.3495047564942574, 'learning_rate': 0.1512331761340626, 'max_depth': 11.0, 'min_child_samples': 18.0, 'n_estimators': 925.0, 'subsample': 0.9111306731162477}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5309033618771202, 'gamma': 0.37741226192478006, 'learning_rate': 0.11908309638352912, 'max_depth': 20.0, 'min_child_samples': 20.0, 'n_estimators': 925.0, 'subsample': 0.8078419882798421}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5788201446580046, 'gamma': 0.30291839798556, 'learning_rate': 0.1714078034758984, 'max_depth': 10.0, 'min_child_samples': 19.0, 'n_estimators': 875.0, 'subsample': 0.99301561013277}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6518740720861601, 'gamma': 0.5079272658797, 'learning_rate': 0.18570492695472982, 'max_depth': 8.0, 'min_child_samples': 9.0, 'n_estimators': 625.0, 'subsample': 0.8031957705146663}
# Accuracy Score 0.833 params {'colsample_bytree': 0.5033598569246016, 'gamma': 0.922727255640982, 'learning_rate': 0.1873730644246493, 'max_depth': 19.0, 'min_child_samples': 17.0, 'n_estimators': 950.0, 'subsample': 0.8165975796008154}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6054055747983962, 'gamma': 0.8764600472017413, 'learning_rate': 0.092273438319132, 'max_depth': 6.0, 'min_child_samples': 5.0, 'n_estimators': 575.0, 'subsample': 0.8213953937005797}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5661225016071507, 'gamma': 0.9379860534270086, 'learning_rate': 0.18383113942387602, 'max_depth': 8.0, 'min_child_samples': 6.0, 'n_estimators': 950.0, 'subsample': 0.8264001757375283}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6734986488756626, 'gamma': 0.05016775372127238, 'learning_rate': 0.1390619167742183, 'max_depth': 9.0, 'min_child_samples': 7.0, 'n_estimators': 450.0, 'subsample': 0.8017095642126943}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5872047879929975, 'gamma': 0.808371450777678, 'learning_rate': 0.19999656195168133, 'max_depth': 6.0, 'min_child_samples': 10.0, 'n_estimators': 600.0, 'subsample': 0.8439729907958091}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6105263509697576, 'gamma': 0.47848376773494455, 'learning_rate': 0.1987403628195483, 'max_depth': 8.0, 'min_child_samples': 8.0, 'n_estimators': 525.0, 'subsample': 0.8717755189024339}
# Accuracy Score 0.767 params {'colsample_bytree': 0.622077374460591, 'gamma': 0.4287360654292006, 'learning_rate': 0.16014439153707483, 'max_depth': 9.0, 'min_child_samples': 8.0, 'n_estimators': 425.0, 'subsample': 0.8572785872320215}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6474494765600685, 'gamma': 0.5329562435412045, 'learning_rate': 0.01195898739604675, 'max_depth': 7.0, 'min_child_samples': 9.0, 'n_estimators': 475.0, 'subsample': 0.8655222515740671}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5950206714444561, 'gamma': 0.41160923596681975, 'learning_rate': 0.14381478681412443, 'max_depth': 10.0, 'min_child_samples': 11.0, 'n_estimators': 500.0, 'subsample': 0.8523134659664487}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6411939671401876, 'gamma': 0.4440519206945773, 'learning_rate': 0.19935680422842728, 'max_depth': 9.0, 'min_child_samples': 8.0, 'n_estimators': 475.0, 'subsample': 0.8610502691887019}
# Accuracy Score 0.800 params {'colsample_bytree': 0.42434628449014683, 'gamma': 0.7925289880496708, 'learning_rate': 0.1031062435635324, 'max_depth': 3.0, 'min_child_samples': 13.0, 'n_estimators': 550.0, 'subsample': 0.8467995133778992}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5461807333197467, 'gamma': 0.46902616706161965, 'learning_rate': 0.006083286372325542, 'max_depth': 7.0, 'min_child_samples': 9.0, 'n_estimators': 525.0, 'subsample': 0.871437091460642}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5685085744100793, 'gamma': 0.7746926835175092, 'learning_rate': 0.06090789418246107, 'max_depth': 4.0, 'min_child_samples': 15.0, 'n_estimators': 500.0, 'subsample': 0.8378333482804647}
# Accuracy Score 0.733 params {'colsample_bytree': 0.6219681579783414, 'gamma': 0.4953790747055518, 'learning_rate': 0.009910455826940655, 'max_depth': 8.0, 'min_child_samples': 7.0, 'n_estimators': 525.0, 'subsample': 0.877431572217797}
# Accuracy Score 0.767 params {'colsample_bytree': 0.4607637609368628, 'gamma': 0.982690409317334, 'learning_rate': 0.06947100242505552, 'max_depth': 3.0, 'min_child_samples': 14.0, 'n_estimators': 550.0, 'subsample': 0.8805911070050091}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5258637542716958, 'gamma': 0.3736052896747991, 'learning_rate': 0.11365851510437044, 'max_depth': 18.0, 'min_child_samples': 9.0, 'n_estimators': 625.0, 'subsample': 0.9037670954684944}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5187298456987999, 'gamma': 0.3357212992830848, 'learning_rate': 0.07876537618706463, 'max_depth': 19.0, 'min_child_samples': 8.0, 'n_estimators': 575.0, 'subsample': 0.8862386778787262}
# Accuracy Score 0.800 params {'colsample_bytree': 0.35757430846177146, 'gamma': 0.8876800532265126, 'learning_rate': 0.13515209550206947, 'max_depth': 6.0, 'min_child_samples': 11.0, 'n_estimators': 400.0, 'subsample': 0.8686684974841113}
# Accuracy Score 0.767 params {'colsample_bytree': 0.3248744243631154, 'gamma': 0.8526368430599044, 'learning_rate': 0.15341869260575308, 'max_depth': 6.0, 'min_child_samples': 12.0, 'n_estimators': 375.0, 'subsample': 0.8642447107823812}
# Accuracy Score 0.767 params {'colsample_bytree': 0.41647895644344834, 'gamma': 0.9037558371255334, 'learning_rate': 0.12498252732755316, 'max_depth': 7.0, 'min_child_samples': 12.0, 'n_estimators': 450.0, 'subsample': 0.8747148184221001}
# Accuracy Score 0.733 params {'colsample_bytree': 0.48279351078951177, 'gamma': 0.5459090093747272, 'learning_rate': 0.057091314689673114, 'max_depth': 17.0, 'min_child_samples': 17.0, 'n_estimators': 425.0, 'subsample': 0.9198268020786518}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5514720683213705, 'gamma': 0.697830546487647, 'learning_rate': 0.024104064999203288, 'max_depth': 4.0, 'min_child_samples': 18.0, 'n_estimators': 450.0, 'subsample': 0.8455710138408915}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5002918435173723, 'gamma': 0.6377982784240935, 'learning_rate': 0.051236066663479275, 'max_depth': 20.0, 'min_child_samples': 16.0, 'n_estimators': 600.0, 'subsample': 0.9007423663998914}
# Accuracy Score 0.767 params {'colsample_bytree': 0.34966281185964154, 'gamma': 0.8331479020968671, 'learning_rate': 0.10945352083697134, 'max_depth': 11.0, 'min_child_samples': 13.0, 'n_estimators': 475.0, 'subsample': 0.8592456411280321}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5739213591523583, 'gamma': 0.6115760159786655, 'learning_rate': 0.09846609656488534, 'max_depth': 4.0, 'min_child_samples': 11.0, 'n_estimators': 725.0, 'subsample': 0.8536519706097759}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5615187542748856, 'gamma': 0.568598221399664, 'learning_rate': 0.08760440824263133, 'max_depth': 3.0, 'min_child_samples': 11.0, 'n_estimators': 575.0, 'subsample': 0.8489901450944798}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5957448086651131, 'gamma': 0.9153529437407631, 'learning_rate': 0.1705398478084514, 'max_depth': 10.0, 'min_child_samples': 20.0, 'n_estimators': 875.0, 'subsample': 0.8200113004481296}
# Accuracy Score 0.800 params {'colsample_bytree': 0.6749023776283051, 'gamma': 0.9998336962431095, 'learning_rate': 0.15622319106728433, 'max_depth': 9.0, 'min_child_samples': 17.0, 'n_estimators': 800.0, 'subsample': 0.8132112724813845}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6394547420820992, 'gamma': 0.9492347300739673, 'learning_rate': 0.01566970223474406, 'max_depth': 8.0, 'min_child_samples': 10.0, 'n_estimators': 825.0, 'subsample': 0.8084831601068831}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6067125727027969, 'gamma': 0.6496388886119818, 'learning_rate': 0.0690409703050915, 'max_depth': 4.0, 'min_child_samples': 12.0, 'n_estimators': 650.0, 'subsample': 0.8403136538545549}
# Accuracy Score 0.800 params {'colsample_bytree': 0.45145750829830966, 'gamma': 0.5176171144828343, 'learning_rate': 0.11956607578367931, 'max_depth': 12.0, 'min_child_samples': 1.0, 'n_estimators': 325.0, 'subsample': 0.8968875646600243}
# Accuracy Score 0.800 params {'colsample_bytree': 0.8298752629896494, 'gamma': 0.3945250733095537, 'learning_rate': 0.14465071085848896, 'max_depth': 15.0, 'min_child_samples': 18.0, 'n_estimators': 250.0, 'subsample': 0.8895115693528253}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6608178196412393, 'gamma': 0.9655257249064821, 'learning_rate': 0.12838453518747425, 'max_depth': 6.0, 'min_child_samples': 13.0, 'n_estimators': 675.0, 'subsample': 0.8043008881051265}
# Accuracy Score 0.767 params {'colsample_bytree': 0.5374913097641862, 'gamma': 0.7517342892869078, 'learning_rate': 0.01853460009322239, 'max_depth': 5.0, 'min_child_samples': 11.0, 'n_estimators': 525.0, 'subsample': 0.8629458039921752}
# Accuracy Score 0.767 params {'colsample_bytree': 0.49286442725289165, 'gamma': 0.6145325340611019, 'learning_rate': 0.11256679848013526, 'max_depth': 19.0, 'min_child_samples': 16.0, 'n_estimators': 550.0, 'subsample': 0.8834929313848453}
# Accuracy Score 0.800 params {'colsample_bytree': 0.48047889276806766, 'gamma': 0.9396551276052768, 'learning_rate': 0.039568601995943926, 'max_depth': 13.0, 'min_child_samples': 18.0, 'n_estimators': 900.0, 'subsample': 0.8187503982752667}
# Accuracy Score 0.767 params {'colsample_bytree': 0.7252580476933744, 'gamma': 0.34273641853699593, 'learning_rate': 0.09480259893424553, 'max_depth': 16.0, 'min_child_samples': 19.0, 'n_estimators': 125.0, 'subsample': 0.9128862598756607}
# Accuracy Score 0.767 params {'colsample_bytree': 0.6884320755581627, 'gamma': 0.805453017341398, 'learning_rate': 0.18318110221201675, 'max_depth': 5.0, 'min_child_samples': 5.0, 'n_estimators': 625.0, 'subsample': 0.8300016638439219}
# Accuracy Score 0.867 params {'colsample_bytree': 0.4715494053301034, 'gamma': 0.9842252595644257, 'learning_rate': 0.1681488277337129, 'max_depth': 12.0, 'min_child_samples': 17.0, 'n_estimators': 1000.0, 'subsample': 0.8094224926459617}
# Accuracy Score 0.800 params {'colsample_bytree': 0.4444702787548792, 'gamma': 0.9993187536489181, 'learning_rate': 0.0752960595720903, 'max_depth': 14.0, 'min_child_samples': 4.0, 'n_estimators': 600.0, 'subsample': 0.8251333612646836}
# Accuracy Score 0.800 params {'colsample_bytree': 0.5846720321452076, 'gamma': 0.9652149256083952, 'learning_rate': 0.1734516428195837, 'max_depth': 12.0, 'min_child_samples': 16.0, 'n_estimators': 850.0, 'subsample': 0.80960517441326}
# 100%|███████████████████████████████████████████████| 500/500 [2:49:38<00:00, 25.09s/it, best loss: 0.1333333333333333]
# {'colsample_bytree': 0.6265915726937883, 'gamma': 0.9013893823196186, 'learning_rate': 0.1653075165723116, 'max_depth': 5.0, 'min_child_samples': 7.0, 'n_estimators': 575.0, 'subsample': 0.8352196979695199}
# Cooresponding loss:
# 0.7

# %%
best
# Out:
# {'colsample_bytree': 0.6265915726937883,
#  'gamma': 0.9013893823196186,
#  'learning_rate': 0.1653075165723116,
#  'max_depth': 5.0,
#  'min_child_samples': 7.0,
#  'n_estimators': 575.0,
#  'subsample': 0.8352196979695199}

# %%
# loop over the number of trials to run
for i in range(0, trial_num):
    # train the model
    print(f"[INFO] training model {i+1} of {trial_num}...")
    clf = xgb.XGBClassifier(n_estimators = int(best['n_estimators']),
                           max_depth = int(best['max_depth']),
                           min_child_samples = best['min_child_samples'],
                           subsample = best['subsample'],
                           learning_rate = best['learning_rate'],
                           gamma = best['gamma'],
                           colsample_bytree = best['colsample_bytree'])
    clf.fit(trainX, trainY)
    
    # make predictions on the testing data and initialize a dictionary to store our computed metreics
    predictions = clf.predict(testX)
    metrics = {}
    
    # compute the confusion matrix and use it to derive the raw accuracy, ensitivity, and specificity
    cm = confusion_matrix(testY, predictions).flatten()
    (tn, fp, fn, tp) = cm
    metrics["acc"] = (tp + tn) / float(cm.sum())
    metrics["sensitivity"] = tp / float(tp + fn)
    metrics["specificity"] = tn / float(tn + fp)
    
    # loop over the metrics
    for (k,v) in metrics.items():
        # update the trialas dictionary with the list of values for the current metric
        l = trials.get(k, [])
        l.append(v)
        trials[k] = l

# loop over our metrics
for metric in ("acc", "sensitivity", "specificity"):
    # grab the list of values for the current metric, then compute the mean and standard deviation
    values = trials[metric]
    mean = np.mean(values)
    std = np.std(values)
    
    # show the computed metrics for the statistic
    print(metric)
    print('='*len(metric))
    print(f'mean={mean:.4f}, std={std:.4f} \n')
# Out:
# [INFO] training model 1 of 5...
# [INFO] training model 2 of 5...
# [INFO] training model 3 of 5...
# [INFO] training model 4 of 5...
# [INFO] training model 5 of 5...
# acc
# ===
# mean=0.8667, std=0.0000
#
# sensitivity
# ===========
# mean=0.8000, std=0.0000
#
# specificity
# ===========
# mean=0.9333, std=0.0000

# %%
trials['acc']
# Out:
# [0.8666666666666667,
#  0.8666666666666667,
#  0.8666666666666667,
#  0.8666666666666667,
#  0.8666666666666667]

# %% [markdown]
# ### Demonstrate testing image predictions

# %%
# randomly select a few images and then initialize the output image for the montage
testingPaths = list(paths.list_images(testingPath))
idxs = np.arange(0, len(testingPaths))
idxs = np.random.choice(idxs, size=(25,), replace=False)
images = []

# loop over the trsting samples
for i in idxs:
    # load the teting image, clone it, and resize it
    image = cv2.imread(testingPaths[i])
    output = image.copy()
    output = cv2.resize(output, (128,128))
    
    # pre-process the image in the same manner we did earlier
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (200, 200))
    image = cv2.threshold(image, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
    
    # quantify the image and make predictions based on the extracted features using the last trained RF
    features = quantify_image(image)
    preds = model.predict([features])
    label = le.inverse_transform(preds)[0]
    
    # draw the colored class label on the output image and add it to the set of output images
    color = (0, 255, 0) if label == "healthy" else (0, 0, 255)
    cv2.putText(output, label, (3, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
    images.append(output)    

# create a montage using 128x128 "titles" with 5 rows and 5 columns
montage = build_montages(images, (128,128), (5,5))[0]
# show the output montage
cv2.imshow("Output", montage)
cv2.waitKey(0)
cv2.destroyAllWindows()
